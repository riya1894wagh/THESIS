# %%
import pandas as pd

# %%
df = pd.read_excel("2023.xlsx")

# %%
df.head(10)
# Out:
#                                     Institute  \
# 0  Indian Institute of Technology Bhubaneswar
# 1  Indian Institute of Technology Bhubaneswar
# 2  Indian Institute of Technology Bhubaneswar
# 3  Indian Institute of Technology Bhubaneswar
# 4  Indian Institute of Technology Bhubaneswar
# 5  Indian Institute of Technology Bhubaneswar
# 6  Indian Institute of Technology Bhubaneswar
# 7  Indian Institute of Technology Bhubaneswar
# 8  Indian Institute of Technology Bhubaneswar
# 9  Indian Institute of Technology Bhubaneswar
#
#                                              Program Quota Seat Type  \
# 0  Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1  Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2  Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3  Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 4  Civil Engineering (4 Years, Bachelor of Techno...    AI   OBC-NCL
# ...

# %%
NIT_Jalandhar = df[df["Institute"] == "Dr. B R Ambedkar National Institute of Technology, Jalandhar"]
NIT_Jalandhar
# Out:
#                                               Institute  \
# 3090  Dr. B R Ambedkar National Institute of Technol...
# 3091  Dr. B R Ambedkar National Institute of Technol...
# 3092  Dr. B R Ambedkar National Institute of Technol...
# 3093  Dr. B R Ambedkar National Institute of Technol...
# 3094  Dr. B R Ambedkar National Institute of Technol...
# ...                                                 ...
# 3350  Dr. B R Ambedkar National Institute of Technol...
# 3351  Dr. B R Ambedkar National Institute of Technol...
# 3352  Dr. B R Ambedkar National Institute of Technol...
# 3353  Dr. B R Ambedkar National Institute of Technol...
# 3354  Dr. B R Ambedkar National Institute of Technol...
#
#                                                 Program Quota Seat Type  \
# 3090   Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 3091   Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 3092   Bio Technology (4 Years, Bachelor of Technology)    HS       EWS
# ...

# %%
NIT_Jaipur = df[df["Institute"] == "Malaviya National Institute of Technology Jaipur"]
NIT_Jaipur
# Out:
#                                              Institute  \
# 3355  Malaviya National Institute of Technology Jaipur
# 3356  Malaviya National Institute of Technology Jaipur
# 3357  Malaviya National Institute of Technology Jaipur
# 3358  Malaviya National Institute of Technology Jaipur
# 3359  Malaviya National Institute of Technology Jaipur
# ...                                                ...
# 3555  Malaviya National Institute of Technology Jaipur
# 3556  Malaviya National Institute of Technology Jaipur
# 3557  Malaviya National Institute of Technology Jaipur
# 3558  Malaviya National Institute of Technology Jaipur
# 3559  Malaviya National Institute of Technology Jaipur
#
#                                                 Program Quota Seat Type  \
# 3355   Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 3356   Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 3357   Architecture (5 Years, Bachelor of Architecture)    HS       EWS
# ...

# %%
NIT_Bhopal = df[df["Institute"] == "Maulana Azad National Institute of Technology Bhopal"]
NIT_Bhopal
# Out:
#                                               Institute  \
# 3560  Maulana Azad National Institute of Technology ...
# 3561  Maulana Azad National Institute of Technology ...
# 3562  Maulana Azad National Institute of Technology ...
# 3563  Maulana Azad National Institute of Technology ...
# 3564  Maulana Azad National Institute of Technology ...
# ...                                                 ...
# 3783  Maulana Azad National Institute of Technology ...
# 3784  Maulana Azad National Institute of Technology ...
# 3785  Maulana Azad National Institute of Technology ...
# 3786  Maulana Azad National Institute of Technology ...
# 3787  Maulana Azad National Institute of Technology ...
#
#                                                Program Quota Seat Type  \
# 3560  Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 3561  Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 3562  Architecture (5 Years, Bachelor of Architecture)    HS       EWS
# ...

# %%
NIT_Allahabad = df[df["Institute"] == "Motilal Nehru National Institute of Technology Allahabad"]
NIT_Allahabad
# Out:
#                                               Institute  \
# 3788  Motilal Nehru National Institute of Technology...
# 3789  Motilal Nehru National Institute of Technology...
# 3790  Motilal Nehru National Institute of Technology...
# 3791  Motilal Nehru National Institute of Technology...
# 3792  Motilal Nehru National Institute of Technology...
# ...                                                 ...
# 3994  Motilal Nehru National Institute of Technology...
# 3995  Motilal Nehru National Institute of Technology...
# 3996  Motilal Nehru National Institute of Technology...
# 3997  Motilal Nehru National Institute of Technology...
# 3998  Motilal Nehru National Institute of Technology...
#
#                                                 Program Quota Seat Type  \
# 3788   Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 3789   Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 3790   Bio Technology (4 Years, Bachelor of Technology)    HS       EWS
# ...

# %%
NIT_Agartala = df[df["Institute"] == "National Institute of Technology Agartala"]
NIT_Agartala
# Out:
#                                       Institute  \
# 3999  National Institute of Technology Agartala
# 4000  National Institute of Technology Agartala
# 4001  National Institute of Technology Agartala
# 4002  National Institute of Technology Agartala
# 4003  National Institute of Technology Agartala
# ...                                         ...
# 4215  National Institute of Technology Agartala
# 4216  National Institute of Technology Agartala
# 4217  National Institute of Technology Agartala
# 4218  National Institute of Technology Agartala
# 4219  National Institute of Technology Agartala
#
#                                                 Program Quota      Seat Type  \
# 3999  Biotechnology and Biochemical Engineering (4 Y...    HS           OPEN
# 4000  Biotechnology and Biochemical Engineering (4 Y...    HS           OPEN
# 4001  Biotechnology and Biochemical Engineering (4 Y...    HS            EWS
# ...

# %%
NIT_Calicut = df[df["Institute"] == "National Institute of Technology Calicut"]
NIT_Calicut
# Out:
#                                      Institute  \
# 4220  National Institute of Technology Calicut
# 4221  National Institute of Technology Calicut
# 4222  National Institute of Technology Calicut
# 4223  National Institute of Technology Calicut
# 4224  National Institute of Technology Calicut
# ...                                        ...
# 4472  National Institute of Technology Calicut
# 4473  National Institute of Technology Calicut
# 4474  National Institute of Technology Calicut
# 4475  National Institute of Technology Calicut
# 4476  National Institute of Technology Calicut
#
#                                                 Program Quota      Seat Type  \
# 4220   Architecture (5 Years, Bachelor of Architecture)    HS           OPEN
# 4221   Architecture (5 Years, Bachelor of Architecture)    HS           OPEN
# 4222   Architecture (5 Years, Bachelor of Architecture)    HS     OPEN (PwD)
# 4223   Architecture (5 Years, Bachelor of Architecture)    HS            EWS
# ...

# %%
NIT_Delhi = df[df["Institute"] == "National Institute of Technology Delhi"]
NIT_Delhi
# Out:
#                                    Institute  \
# 4477  National Institute of Technology Delhi
# 4478  National Institute of Technology Delhi
# 4479  National Institute of Technology Delhi
# 4480  National Institute of Technology Delhi
# 4481  National Institute of Technology Delhi
# ...                                      ...
# 4587  National Institute of Technology Delhi
# 4588  National Institute of Technology Delhi
# 4589  National Institute of Technology Delhi
# 4590  National Institute of Technology Delhi
# 4591  National Institute of Technology Delhi
#
#                                                 Program Quota Seat Type  \
# 4477  Artificial Intelligence and Data Science (4 Ye...    HS      OPEN
# 4478  Artificial Intelligence and Data Science (4 Ye...    HS      OPEN
# 4479  Artificial Intelligence and Data Science (4 Ye...    HS       EWS
# 4480  Artificial Intelligence and Data Science (4 Ye...    HS   OBC-NCL
# ...

# %%
NIT_Durgapur = df[df["Institute"] == "National Institute of Technology Durgapur"]
NIT_Durgapur
# Out:
#                                       Institute  \
# 4592  National Institute of Technology Durgapur
# 4593  National Institute of Technology Durgapur
# 4594  National Institute of Technology Durgapur
# 4595  National Institute of Technology Durgapur
# 4596  National Institute of Technology Durgapur
# ...                                         ...
# 4806  National Institute of Technology Durgapur
# 4807  National Institute of Technology Durgapur
# 4808  National Institute of Technology Durgapur
# 4809  National Institute of Technology Durgapur
# 4810  National Institute of Technology Durgapur
#
#                                                 Program Quota      Seat Type  \
# 4592   Bio Technology (4 Years, Bachelor of Technology)    HS           OPEN
# 4593   Bio Technology (4 Years, Bachelor of Technology)    HS           OPEN
# 4594   Bio Technology (4 Years, Bachelor of Technology)    HS     OPEN (PwD)
# ...

# %%
NIT_Goa = df[df["Institute"] == "National Institute of Technology Goa"]
NIT_Goa
# Out:
#                                  Institute  \
# 4811  National Institute of Technology Goa
# 4812  National Institute of Technology Goa
# 4813  National Institute of Technology Goa
# 4814  National Institute of Technology Goa
# 4815  National Institute of Technology Goa
# ...                                    ...
# 4904  National Institute of Technology Goa
# 4905  National Institute of Technology Goa
# 4906  National Institute of Technology Goa
# 4907  National Institute of Technology Goa
# 4908  National Institute of Technology Goa
#
#                                                 Program Quota      Seat Type  \
# 4811  Civil Engineering (4 Years, Bachelor of Techno...    GO           OPEN
# 4812  Civil Engineering (4 Years, Bachelor of Techno...    GO           OPEN
# 4813  Civil Engineering (4 Years, Bachelor of Techno...    GO        OBC-NCL
# 4814  Civil Engineering (4 Years, Bachelor of Techno...    GO        OBC-NCL
# ...

# %%
NIT_Hamirpur = df[df["Institute"] == "National Institute of Technology Hamirpur"]
NIT_Hamirpur
# Out:
#                                       Institute  \
# 4909  National Institute of Technology Hamirpur
# 4910  National Institute of Technology Hamirpur
# 4911  National Institute of Technology Hamirpur
# 4912  National Institute of Technology Hamirpur
# 4913  National Institute of Technology Hamirpur
# ...                                         ...
# 5143  National Institute of Technology Hamirpur
# 5144  National Institute of Technology Hamirpur
# 5145  National Institute of Technology Hamirpur
# 5146  National Institute of Technology Hamirpur
# 5147  National Institute of Technology Hamirpur
#
#                                                 Program Quota Seat Type  \
# 4909   Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 4910   Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 4911   Architecture (5 Years, Bachelor of Architecture)    HS       EWS
# 4912   Architecture (5 Years, Bachelor of Architecture)    HS       EWS
# ...

# %%
NIT_Surathkal = df[df["Institute"] == "National Institute of Technology Karnataka, Surathkal"]
NIT_Surathkal
# Out:
#                                               Institute  \
# 5148  National Institute of Technology Karnataka, Su...
# 5149  National Institute of Technology Karnataka, Su...
# 5150  National Institute of Technology Karnataka, Su...
# 5151  National Institute of Technology Karnataka, Su...
# 5152  National Institute of Technology Karnataka, Su...
# ...                                                 ...
# 5391  National Institute of Technology Karnataka, Su...
# 5392  National Institute of Technology Karnataka, Su...
# 5393  National Institute of Technology Karnataka, Su...
# 5394  National Institute of Technology Karnataka, Su...
# 5395  National Institute of Technology Karnataka, Su...
#
#                                                 Program Quota Seat Type  \
# 5148  Artificial Intelligence (4 Years, Bachelor of ...    HS      OPEN
# 5149  Artificial Intelligence (4 Years, Bachelor of ...    HS      OPEN
# 5150  Artificial Intelligence (4 Years, Bachelor of ...    HS       EWS
# ...

# %%
NIT_Meghalaya = df[df["Institute"] == "National Institute of Technology Meghalaya"]
NIT_Meghalaya
# Out:
#                                        Institute  \
# 5396  National Institute of Technology Meghalaya
# 5397  National Institute of Technology Meghalaya
# 5398  National Institute of Technology Meghalaya
# 5399  National Institute of Technology Meghalaya
# 5400  National Institute of Technology Meghalaya
# ...                                          ...
# 5458  National Institute of Technology Meghalaya
# 5459  National Institute of Technology Meghalaya
# 5460  National Institute of Technology Meghalaya
# 5461  National Institute of Technology Meghalaya
# 5462  National Institute of Technology Meghalaya
#
#                                                 Program Quota Seat Type  \
# 5396  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 5397  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 5398  Civil Engineering (4 Years, Bachelor of Techno...    HS        ST
# 5399  Civil Engineering (4 Years, Bachelor of Techno...    HS        ST
# ...

# %%
NIT_Nagaland = df[df["Institute"] == "National Institute of Technology Nagaland"]
NIT_Nagaland
# Out:
#                                       Institute  \
# 5463  National Institute of Technology Nagaland
# 5464  National Institute of Technology Nagaland
# 5465  National Institute of Technology Nagaland
# 5466  National Institute of Technology Nagaland
# 5467  National Institute of Technology Nagaland
# 5468  National Institute of Technology Nagaland
# 5469  National Institute of Technology Nagaland
# 5470  National Institute of Technology Nagaland
# 5471  National Institute of Technology Nagaland
# 5472  National Institute of Technology Nagaland
# 5473  National Institute of Technology Nagaland
# 5474  National Institute of Technology Nagaland
# 5475  National Institute of Technology Nagaland
# 5476  National Institute of Technology Nagaland
# 5477  National Institute of Technology Nagaland
# 5478  National Institute of Technology Nagaland
# 5479  National Institute of Technology Nagaland
# 5480  National Institute of Technology Nagaland
# ...

# %%
NIT_Patna = df[df["Institute"] == "National Institute of Technology Patna"]
NIT_Patna
# Out:
#                                    Institute  \
# 5518  National Institute of Technology Patna
# 5519  National Institute of Technology Patna
# 5520  National Institute of Technology Patna
# 5521  National Institute of Technology Patna
# 5522  National Institute of Technology Patna
# ...                                      ...
# 5774  National Institute of Technology Patna
# 5775  National Institute of Technology Patna
# 5776  National Institute of Technology Patna
# 5777  National Institute of Technology Patna
# 5778  National Institute of Technology Patna
#
#                                                 Program Quota Seat Type  \
# 5518   Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 5519   Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 5520   Architecture (5 Years, Bachelor of Architecture)    HS       EWS
# 5521   Architecture (5 Years, Bachelor of Architecture)    HS       EWS
# ...

# %%
NIT_Puducherry = df[df["Institute"] == "National Institute of Technology Puducherry"]
NIT_Puducherry
# Out:
#                                         Institute  \
# 5779  National Institute of Technology Puducherry
# 5780  National Institute of Technology Puducherry
# 5781  National Institute of Technology Puducherry
# 5782  National Institute of Technology Puducherry
# 5783  National Institute of Technology Puducherry
# ...                                           ...
# 5863  National Institute of Technology Puducherry
# 5864  National Institute of Technology Puducherry
# 5865  National Institute of Technology Puducherry
# 5866  National Institute of Technology Puducherry
# 5867  National Institute of Technology Puducherry
#
#                                                 Program Quota Seat Type  \
# 5779  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 5780  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 5781  Civil Engineering (4 Years, Bachelor of Techno...    HS       EWS
# ...

# %%
NIT_Raipur = df[df["Institute"] == "National Institute of Technology Raipur"]
NIT_Raipur
# Out:
#                                     Institute  \
# 5868  National Institute of Technology Raipur
# 5869  National Institute of Technology Raipur
# 5870  National Institute of Technology Raipur
# 5871  National Institute of Technology Raipur
# 5872  National Institute of Technology Raipur
# ...                                       ...
# 6122  National Institute of Technology Raipur
# 6123  National Institute of Technology Raipur
# 6124  National Institute of Technology Raipur
# 6125  National Institute of Technology Raipur
# 6126  National Institute of Technology Raipur
#
#                                                 Program Quota Seat Type  \
# 5868   Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 5869   Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 5870   Architecture (5 Years, Bachelor of Architecture)    HS       EWS
# 5871   Architecture (5 Years, Bachelor of Architecture)    HS       EWS
# ...

# %%
NIT_Sikkim = df[df["Institute"] == "National Institute of Technology Sikkim"]
NIT_Sikkim
# Out:
#                                     Institute  \
# 6127  National Institute of Technology Sikkim
# 6128  National Institute of Technology Sikkim
# 6129  National Institute of Technology Sikkim
# 6130  National Institute of Technology Sikkim
# 6131  National Institute of Technology Sikkim
# ...                                       ...
# 6186  National Institute of Technology Sikkim
# 6187  National Institute of Technology Sikkim
# 6188  National Institute of Technology Sikkim
# 6189  National Institute of Technology Sikkim
# 6190  National Institute of Technology Sikkim
#
#                                                 Program Quota Seat Type  \
# 6127  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6128  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6129  Civil Engineering (4 Years, Bachelor of Techno...    HS   OBC-NCL
# 6130  Civil Engineering (4 Years, Bachelor of Techno...    HS   OBC-NCL
# ...

# %%
NIT_Arunachal_Pradesh = df[df["Institute"] == "National Institute of Technology Arunachal Pradesh"]
NIT_Arunachal_Pradesh
# Out:
#                                               Institute  \
# 6191  National Institute of Technology Arunachal Pra...
# 6192  National Institute of Technology Arunachal Pra...
# 6193  National Institute of Technology Arunachal Pra...
# 6194  National Institute of Technology Arunachal Pra...
# 6195  National Institute of Technology Arunachal Pra...
# ...                                                 ...
# 6251  National Institute of Technology Arunachal Pra...
# 6252  National Institute of Technology Arunachal Pra...
# 6253  National Institute of Technology Arunachal Pra...
# 6254  National Institute of Technology Arunachal Pra...
# 6255  National Institute of Technology Arunachal Pra...
#
#                                                 Program Quota Seat Type  \
# 6191  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6192  Civil Engineering (4 Years, Bachelor of Techno...    HS       EWS
# 6193  Civil Engineering (4 Years, Bachelor of Techno...    HS   OBC-NCL
# ...

# %%
NIT_Jamshedpur = df[df["Institute"] == "National Institute of Technology, Jamshedpur"]
NIT_Jamshedpur
# Out:
#                                          Institute  \
# 6256  National Institute of Technology, Jamshedpur
# 6257  National Institute of Technology, Jamshedpur
# 6258  National Institute of Technology, Jamshedpur
# 6259  National Institute of Technology, Jamshedpur
# 6260  National Institute of Technology, Jamshedpur
# ...                                            ...
# 6428  National Institute of Technology, Jamshedpur
# 6429  National Institute of Technology, Jamshedpur
# 6430  National Institute of Technology, Jamshedpur
# 6431  National Institute of Technology, Jamshedpur
# 6432  National Institute of Technology, Jamshedpur
#
#                                                 Program Quota   Seat Type  \
# 6256  Civil Engineering (4 Years, Bachelor of Techno...    HS        OPEN
# 6257  Civil Engineering (4 Years, Bachelor of Techno...    HS        OPEN
# 6258  Civil Engineering (4 Years, Bachelor of Techno...    HS  OPEN (PwD)
# ...

# %%
NIT_Kurukshetra= df[df["Institute"] == "National Institute of Technology, Kurukshetra"]
NIT_Kurukshetra
# Out:
#                                           Institute  \
# 6433  National Institute of Technology, Kurukshetra
# 6434  National Institute of Technology, Kurukshetra
# 6435  National Institute of Technology, Kurukshetra
# 6436  National Institute of Technology, Kurukshetra
# 6437  National Institute of Technology, Kurukshetra
# ...                                             ...
# 6649  National Institute of Technology, Kurukshetra
# 6650  National Institute of Technology, Kurukshetra
# 6651  National Institute of Technology, Kurukshetra
# 6652  National Institute of Technology, Kurukshetra
# 6653  National Institute of Technology, Kurukshetra
#
#                                                 Program Quota   Seat Type  \
# 6433  Artificial Intelligence and Machine Learning (...    HS        OPEN
# 6434  Artificial Intelligence and Machine Learning (...    HS        OPEN
# 6435  Artificial Intelligence and Machine Learning (...    HS  OPEN (PwD)
# ...

# %%
NIT_Manipur = df[df["Institute"] == "National Institute of Technology, Manipur"]
NIT_Manipur
# Out:
#                                       Institute  \
# 6654  National Institute of Technology, Manipur
# 6655  National Institute of Technology, Manipur
# 6656  National Institute of Technology, Manipur
# 6657  National Institute of Technology, Manipur
# 6658  National Institute of Technology, Manipur
# ...                                         ...
# 6722  National Institute of Technology, Manipur
# 6723  National Institute of Technology, Manipur
# 6724  National Institute of Technology, Manipur
# 6725  National Institute of Technology, Manipur
# 6726  National Institute of Technology, Manipur
#
#                                                 Program Quota Seat Type  \
# 6654  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6655  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6656  Civil Engineering (4 Years, Bachelor of Techno...    HS   OBC-NCL
# 6657  Civil Engineering (4 Years, Bachelor of Techno...    HS   OBC-NCL
# ...

# %%
NIT_Mizoram = df[df["Institute"] == "National Institute of Technology, Mizoram"]
NIT_Mizoram
# Out:
#                                       Institute  \
# 6727  National Institute of Technology, Mizoram
# 6728  National Institute of Technology, Mizoram
# 6729  National Institute of Technology, Mizoram
# 6730  National Institute of Technology, Mizoram
# 6731  National Institute of Technology, Mizoram
# ...                                         ...
# 6791  National Institute of Technology, Mizoram
# 6792  National Institute of Technology, Mizoram
# 6793  National Institute of Technology, Mizoram
# 6794  National Institute of Technology, Mizoram
# 6795  National Institute of Technology, Mizoram
#
#                                                 Program Quota Seat Type  \
# 6727  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6728  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 6729  Civil Engineering (4 Years, Bachelor of Techno...    HS        ST
# 6730  Civil Engineering (4 Years, Bachelor of Techno...    HS        ST
# ...

# %%
NIT_Rourkela = df[df["Institute"] == "National Institute of Technology, Rourkela"]
NIT_Rourkela
# Out:
#                                        Institute  \
# 6796  National Institute of Technology, Rourkela
# 6797  National Institute of Technology, Rourkela
# 6798  National Institute of Technology, Rourkela
# 6799  National Institute of Technology, Rourkela
# 6800  National Institute of Technology, Rourkela
# ...                                          ...
# 7188  National Institute of Technology, Rourkela
# 7189  National Institute of Technology, Rourkela
# 7190  National Institute of Technology, Rourkela
# 7191  National Institute of Technology, Rourkela
# 7192  National Institute of Technology, Rourkela
#
#                                                Program Quota Seat Type  \
# 6796  Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 6797  Architecture (5 Years, Bachelor of Architecture)    HS      OPEN
# 6798  Architecture (5 Years, Bachelor of Architecture)    HS       EWS
# 6799  Architecture (5 Years, Bachelor of Architecture)    HS   OBC-NCL
# ...

# %%
NIT_Silchar = df[df["Institute"] == "National Institute of Technology, Silchar"]
NIT_Silchar
# Out:
#                                       Institute  \
# 7193  National Institute of Technology, Silchar
# 7194  National Institute of Technology, Silchar
# 7195  National Institute of Technology, Silchar
# 7196  National Institute of Technology, Silchar
# 7197  National Institute of Technology, Silchar
# ...                                         ...
# 7331  National Institute of Technology, Silchar
# 7332  National Institute of Technology, Silchar
# 7333  National Institute of Technology, Silchar
# 7334  National Institute of Technology, Silchar
# 7335  National Institute of Technology, Silchar
#
#                                                 Program Quota      Seat Type  \
# 7193  Civil Engineering (4 Years, Bachelor of Techno...    HS           OPEN
# 7194  Civil Engineering (4 Years, Bachelor of Techno...    HS           OPEN
# 7195  Civil Engineering (4 Years, Bachelor of Techno...    HS     OPEN (PwD)
# ...

# %%
NIT_Srinagar = df[df["Institute"] == "National Institute of Technology, Srinagar"]
NIT_Srinagar
# Out:
#                                        Institute  \
# 7336  National Institute of Technology, Srinagar
# 7337  National Institute of Technology, Srinagar
# 7338  National Institute of Technology, Srinagar
# 7339  National Institute of Technology, Srinagar
# 7340  National Institute of Technology, Srinagar
# ...                                          ...
# 7517  National Institute of Technology, Srinagar
# 7518  National Institute of Technology, Srinagar
# 7519  National Institute of Technology, Srinagar
# 7520  National Institute of Technology, Srinagar
# 7521  National Institute of Technology, Srinagar
#
#                                                 Program Quota   Seat Type  \
# 7336  Chemical Engineering (4 Years, Bachelor of Tec...    JK        OPEN
# 7337  Chemical Engineering (4 Years, Bachelor of Tec...    JK        OPEN
# 7338  Chemical Engineering (4 Years, Bachelor of Tec...    JK  OPEN (PwD)
# 7339  Chemical Engineering (4 Years, Bachelor of Tec...    JK         EWS
# ...

# %%
NIT_Tiruchirappalli = df[df["Institute"] == "National Institute of Technology, Tiruchirappalli"]
NIT_Tiruchirappalli
# Out:
#                                               Institute  \
# 7522  National Institute of Technology, Tiruchirappalli
# 7523  National Institute of Technology, Tiruchirappalli
# 7524  National Institute of Technology, Tiruchirappalli
# 7525  National Institute of Technology, Tiruchirappalli
# 7526  National Institute of Technology, Tiruchirappalli
# ...                                                 ...
# 7756  National Institute of Technology, Tiruchirappalli
# 7757  National Institute of Technology, Tiruchirappalli
# 7758  National Institute of Technology, Tiruchirappalli
# 7759  National Institute of Technology, Tiruchirappalli
# 7760  National Institute of Technology, Tiruchirappalli
#
#                                                 Program Quota      Seat Type  \
# 7522   Architecture (5 Years, Bachelor of Architecture)    HS           OPEN
# 7523   Architecture (5 Years, Bachelor of Architecture)    HS           OPEN
# ...

# %%
NIT_Uttarakhand = df[df["Institute"] == "National Institute of Technology, Uttarakhand"]
NIT_Uttarakhand
# Out:
#                                           Institute  \
# 7761  National Institute of Technology, Uttarakhand
# 7762  National Institute of Technology, Uttarakhand
# 7763  National Institute of Technology, Uttarakhand
# 7764  National Institute of Technology, Uttarakhand
# 7765  National Institute of Technology, Uttarakhand
# ...                                             ...
# 7840  National Institute of Technology, Uttarakhand
# 7841  National Institute of Technology, Uttarakhand
# 7842  National Institute of Technology, Uttarakhand
# 7843  National Institute of Technology, Uttarakhand
# 7844  National Institute of Technology, Uttarakhand
#
#                                                 Program Quota Seat Type  \
# 7761  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 7762  Civil Engineering (4 Years, Bachelor of Techno...    HS      OPEN
# 7763  Civil Engineering (4 Years, Bachelor of Techno...    HS       EWS
# ...

# %%
NIT_Warangal = df[df["Institute"] == "National Institute of Technology, Warangal"]
NIT_Warangal
# Out:
#                                        Institute  \
# 7845  National Institute of Technology, Warangal
# 7846  National Institute of Technology, Warangal
# 7847  National Institute of Technology, Warangal
# 7848  National Institute of Technology, Warangal
# 7849  National Institute of Technology, Warangal
# ...                                          ...
# 8102  National Institute of Technology, Warangal
# 8103  National Institute of Technology, Warangal
# 8104  National Institute of Technology, Warangal
# 8105  National Institute of Technology, Warangal
# 8106  National Institute of Technology, Warangal
#
#                                                Program Quota   Seat Type  \
# 7845  Bio Technology (4 Years, Bachelor of Technology)    HS        OPEN
# 7846  Bio Technology (4 Years, Bachelor of Technology)    HS        OPEN
# 7847  Bio Technology (4 Years, Bachelor of Technology)    HS  OPEN (PwD)
# 7848  Bio Technology (4 Years, Bachelor of Technology)    HS         EWS
# ...

# %%
NIT_Surat = df[df["Institute"] == "Sardar Vallabhbhai National Institute of Technology, Surat"]
NIT_Surat
# Out:
#                                               Institute  \
# 8107  Sardar Vallabhbhai National Institute of Techn...
# 8108  Sardar Vallabhbhai National Institute of Techn...
# 8109  Sardar Vallabhbhai National Institute of Techn...
# 8110  Sardar Vallabhbhai National Institute of Techn...
# 8111  Sardar Vallabhbhai National Institute of Techn...
# ...                                                 ...
# 8302  Sardar Vallabhbhai National Institute of Techn...
# 8303  Sardar Vallabhbhai National Institute of Techn...
# 8304  Sardar Vallabhbhai National Institute of Techn...
# 8305  Sardar Vallabhbhai National Institute of Techn...
# 8306  Sardar Vallabhbhai National Institute of Techn...
#
#                                                 Program Quota   Seat Type  \
# 8107  Artificial Intelligence (4 Years, Bachelor of ...    HS        OPEN
# 8108  Artificial Intelligence (4 Years, Bachelor of ...    HS        OPEN
# ...

# %%
NIT_Nagpur = df[df["Institute"] == "Visvesvaraya National Institute of Technology, Nagpur"]
NIT_Nagpur
# Out:
#                                               Institute  \
# 8307  Visvesvaraya National Institute of Technology,...
# 8308  Visvesvaraya National Institute of Technology,...
# 8309  Visvesvaraya National Institute of Technology,...
# 8310  Visvesvaraya National Institute of Technology,...
# 8311  Visvesvaraya National Institute of Technology,...
# ...                                                 ...
# 8510  Visvesvaraya National Institute of Technology,...
# 8511  Visvesvaraya National Institute of Technology,...
# 8512  Visvesvaraya National Institute of Technology,...
# 8513  Visvesvaraya National Institute of Technology,...
# 8514  Visvesvaraya National Institute of Technology,...
#
#                                                 Program Quota   Seat Type  \
# 8307   Architecture (5 Years, Bachelor of Architecture)    HS        OPEN
# 8308   Architecture (5 Years, Bachelor of Architecture)    HS        OPEN
# ...

# %%
NIT_Andhra_Pradesh = df[df["Institute"] == "National Institute of Technology, Andhra Pradesh"]
NIT_Andhra_Pradesh
# Out:
#                                              Institute  \
# 8515  National Institute of Technology, Andhra Pradesh
# 8516  National Institute of Technology, Andhra Pradesh
# 8517  National Institute of Technology, Andhra Pradesh
# 8518  National Institute of Technology, Andhra Pradesh
# 8519  National Institute of Technology, Andhra Pradesh
# ...                                                ...
# 8675  National Institute of Technology, Andhra Pradesh
# 8676  National Institute of Technology, Andhra Pradesh
# 8677  National Institute of Technology, Andhra Pradesh
# 8678  National Institute of Technology, Andhra Pradesh
# 8679  National Institute of Technology, Andhra Pradesh
#
#                                                 Program Quota   Seat Type  \
# 8515   Bio Technology (4 Years, Bachelor of Technology)    HS        OPEN
# 8516   Bio Technology (4 Years, Bachelor of Technology)    HS        OPEN
# 8517   Bio Technology (4 Years, Bachelor of Technology)    HS  OPEN (PwD)
# ...

# %%
df_list = [NIT_Agartala,NIT_Allahabad,NIT_Andhra_Pradesh,NIT_Arunachal_Pradesh,NIT_Bhopal,NIT_Calicut,NIT_Delhi,
          NIT_Durgapur,NIT_Goa,NIT_Hamirpur,NIT_Jaipur,NIT_Jalandhar,NIT_Jamshedpur,NIT_Kurukshetra,NIT_Manipur,NIT_Meghalaya,
          NIT_Mizoram,NIT_Nagaland,NIT_Nagpur,NIT_Puducherry,NIT_Patna,NIT_Rourkela,NIT_Raipur,NIT_Sikkim,NIT_Silchar,
          NIT_Srinagar,NIT_Surat,NIT_Surathkal,NIT_Tiruchirappalli,NIT_Uttarakhand,NIT_Warangal]

# %%
NIT = pd.concat(df_list , axis=0 , ignore_index=True)

# %%
NIT.to_csv("2023_csv")

# %%
NIT.shape
# Out:
# (5590, 8)

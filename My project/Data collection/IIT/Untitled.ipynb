# %%
import pandas as pd

# %%
l1 = pd.read_csv("IIT_Training")

# %%
l1 = l1.drop(columns=["Unnamed: 0.1","Unnamed: 0"])

# %%
l2 = pd.read_csv("IIT_2023")

# %%
l2.drop(columns="Unnamed: 0",inplace=True)

# %%
df_list = [l1,l2]

# %%
df = pd.concat(df_list)

# %%
df
# Out:
#                                           Institute  \
# 0             Indian Institute of Technology Bhilai
# 1             Indian Institute of Technology Bhilai
# 2             Indian Institute of Technology Bhilai
# 3             Indian Institute of Technology Bhilai
# 4             Indian Institute of Technology Bhilai
# ...                                             ...
# 3061  Indian Institute of Technology (BHU) Varanasi
# 3062  Indian Institute of Technology (BHU) Varanasi
# 3063  Indian Institute of Technology (BHU) Varanasi
# 3064  Indian Institute of Technology (BHU) Varanasi
# 3065  Indian Institute of Technology (BHU) Varanasi
#
#                                                 Program Quota Seat Type  \
# 0     Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 1     Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 2     Computer Science and Engineering (4 Years, Bac...    AI   OBC-NCL
# ...

# %%
df.shape
# Out:
# (82149, 9)

# %%
import pandas as pd
df = pd.read_csv("IIT_Training")

# %%
# Computer Science and Engineering (4 Years, Bachelor of Technology) # 0
Computer_Science_and_Engineering = df[df["Program"] == "Computer Science and Engineering (4 Years, Bachelor of Technology)"]
Computer_Science_and_Engineering["Duration"] = "4 Years"
Computer_Science_and_Engineering["Degree"] = "Bachelor of Technology"
Computer_Science_and_Engineering["Branch"] = "Computer Science and Engineering"
Computer_Science_and_Engineering = Computer_Science_and_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Electrical Engineering (4 Years, Bachelor of Technology) #1

Electrical_Engineering = df[df["Program"] == "Electrical Engineering (4 Years, Bachelor of Technology)"]
Electrical_Engineering["Duration"] = "4 Years"
Electrical_Engineering["Degree"] = "Bachelor of Technology"
Electrical_Engineering["Branch"] = "Electrical_Engineering"
Electrical_Engineering = Electrical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Mechanical Engineering (4 Years, Bachelor of Technology) #2
Mechanical_Engineering = df[df["Program"] == "Mechanical Engineering (4 Years, Bachelor of Technology)"]
Mechanical_Engineering["Duration"] = "4 Years"
Mechanical_Engineering["Degree"] = "Bachelor of Technology"
Mechanical_Engineering["Branch"] = "Mechanical Engineering"
Mechanical_Engineering = Mechanical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Civil Engineering (4 Years, Bachelor of Technology) #3
Civil_Engineering = df[df["Program"] == "Civil Engineering (4 Years, Bachelor of Technology)"]
Civil_Engineering["Duration"] = "4 Years"
Civil_Engineering["Degree"] = "Bachelor of Technology"
Civil_Engineering["Branch"] = "Civil Engineering"
Civil_Engineering = Civil_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Civil Engineering and M. Tech. in Structural Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) #4
Civil_Engineering_Dual_Structural_Engineering = df[df["Program"] == "Civil Engineering and M. Tech. in Structural Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Civil_Engineering_Dual_Structural_Engineering["Duration"] = "5 Years"
Civil_Engineering_Dual_Structural_Engineering["Degree"] = "Bachelor and Master of Technology"
Civil_Engineering_Dual_Structural_Engineering["Branch"] = "Civil Engineering and M. Tech. in Structural Engineering"
Civil_Engineering_Dual_Structural_Engineering = Civil_Engineering_Dual_Structural_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Civil Engineering and M.Tech in Transportation Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) #5
Civil_Engineering_Dual_Transportation_Engineering = df[df["Program"] == "Civil Engineering and M.Tech in Transportation Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Civil_Engineering_Dual_Transportation_Engineering["Duration"] = "5 Years"
Civil_Engineering_Dual_Transportation_Engineering["Degree"] = "Bachelor and Master of Technology"
Civil_Engineering_Dual_Transportation_Engineering["Branch"] = "Civil Engineering and M.Tech in Transportation Engineering"
Civil_Engineering_Dual_Transportation_Engineering = Civil_Engineering_Dual_Transportation_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Civil Engineering and M.Tech. in Environmental Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) #6

Civil_Engineering_Dual_Environmental_Engineering = df[df["Program"] == "Civil Engineering and M.Tech. in Environmental Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Civil_Engineering_Dual_Environmental_Engineering["Duration"] = "5 Years"
Civil_Engineering_Dual_Environmental_Engineering["Degree"] = "Bachelor and Master of Technology"
Civil_Engineering_Dual_Environmental_Engineering["Branch"] = "Civil Engineering and M.Tech. in Environmental Engineering"
Civil_Engineering_Dual_Environmental_Engineering = Civil_Engineering_Dual_Environmental_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Computer Science and Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) #7
Computer_Science_and_Engineering_Dual = df[df["Program"] == "Computer Science and Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Computer_Science_and_Engineering_Dual["Duration"] = "5 Years"
Computer_Science_and_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Computer_Science_and_Engineering_Dual["Branch"] = "Computer Science and Engineering"
Computer_Science_and_Engineering_Dual = Computer_Science_and_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
    
# Electrical Engineering and M.Tech Power Electronics and Drives (5 Years, Bachelor and Master of Technology (Dual Degree)) #8
Electrical_Engineering_Dual_Power_Electronics_and_Drives = df[df["Program"] == "Electrical Engineering and M.Tech Power Electronics and Drives (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Electrical_Engineering_Dual_Power_Electronics_and_Drives["Duration"] = "5 Years"
Electrical_Engineering_Dual_Power_Electronics_and_Drives["Degree"] = "Bachelor and Master of Technology"
Electrical_Engineering_Dual_Power_Electronics_and_Drives["Branch"] = "Electrical Engineering Dual Power Electronics and Drives"
Electrical_Engineering_Dual_Power_Electronics_and_Drives = Electrical_Engineering_Dual_Power_Electronics_and_Drives.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Electronics and Communication Engineering (4 Years, Bachelor of Technology) # 9 
Electronics_and_Communication_Engineering = df[df["Program"] == "Electronics and Communication Engineering (4 Years, Bachelor of Technology)"]
Electronics_and_Communication_Engineering["Duration"] = "4 Years"
Electronics_and_Communication_Engineering["Degree"] = "Bachelor of Technology"
Electronics_and_Communication_Engineering["Branch"] = "Electronics and Communication Engineering"
Electronics_and_Communication_Engineering = Electronics_and_Communication_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Mechanical Engineering and M. Tech. in Mechanical System Design (5 Years, Bachelor and Master of Technology (Dual Degree)) #10
Mechanical_Engineering_Dual_System_Design = df[df["Program"] == "Mechanical Engineering and M. Tech. in Mechanical System Design (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Mechanical_Engineering_Dual_System_Design["Duration"] = "5 Years"
Mechanical_Engineering_Dual_System_Design["Degree"] = "Bachelor and Master of Technology"
Mechanical_Engineering_Dual_System_Design["Branch"] = "Mechanical Engineering in System Design"
Mechanical_Engineering_Dual_System_Design = Mechanical_Engineering_Dual_System_Design.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Mechanical Engineering and M. Tech. in Thermal Science & Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) #11
Mechanical_Engineering_Dual_Thermal_Science = df[df["Program"] == "Mechanical Engineering and M. Tech. in Thermal Science & Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Mechanical_Engineering_Dual_Thermal_Science["Duration"] = "5 Years"
Mechanical_Engineering_Dual_Thermal_Science["Degree"] = "Bachelor and Master of Technology"
Mechanical_Engineering_Dual_Thermal_Science["Branch"] = "Mechanical Engineering in Thermal Science"
Mechanical_Engineering_Dual_Thermal_Science = Mechanical_Engineering_Dual_Thermal_Science.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Mechanical Engineering with M.Tech. in Manufacturing Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) #12
Mechanical_Engineering_Dual_Manufacturing_Engineering = df[df["Program"] == "Mechanical Engineering with M.Tech. in Manufacturing Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Mechanical_Engineering_Dual_Manufacturing_Engineering["Duration"] = "5 Years"
Mechanical_Engineering_Dual_Manufacturing_Engineering["Degree"] = "Bachelor and Master of Technology"
Mechanical_Engineering_Dual_Manufacturing_Engineering["Branch"] = "Mechanical Engineering in Manufacturing Engineering"
Mechanical_Engineering_Dual_Manufacturing_Engineering = Mechanical_Engineering_Dual_Manufacturing_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Metallurgical and Materials Engineering (4 Years, Bachelor of Technology) #13
Metallurgical_Engineering_and_Materials_Science = df[df["Program"] == "Metallurgical Engineering and Materials Science (4 Years, Bachelor of Technology)"]
Metallurgical_Engineering_and_Materials_Science["Duration"] = "4 Years"
Metallurgical_Engineering_and_Materials_Science["Degree"] = "Bachelor of Technology"
Metallurgical_Engineering_and_Materials_Science["Branch"] = "Metallurgical Engineering and Materials Science"
Metallurgical_Engineering_and_Materials_Science = Metallurgical_Engineering_and_Materials_Science.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Metallurgical and Materials Engineering and M.Tech. in Materials Science and Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))
Metallurgical_and_Materials_Engineering_Dual_Materials_Science_and_Engineering = df[df["Program"] == "Metallurgical and Materials Engineering and M.Tech. in Materials Science and Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Metallurgical_and_Materials_Engineering_Dual_Materials_Science_and_Engineering["Duration"] = "5 Years"
Metallurgical_and_Materials_Engineering_Dual_Materials_Science_and_Engineering["Degree"] = "Bachelor and Master of Technology"
Metallurgical_and_Materials_Engineering_Dual_Materials_Science_and_Engineering["Branch"] = "Metallurgical and Materials Engineering"
Metallurgical_and_Materials_Engineering_Dual_Materials_Science_and_Engineering = Metallurgical_and_Materials_Engineering_Dual_Materials_Science_and_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Aerospace Engineering (4 Years, Bachelor of Technology) #15
Aerospace_Engineering = df[df["Program"] == "Aerospace Engineering (4 Years, Bachelor of Technology)"]
Aerospace_Engineering["Duration"] = "4 Years"
Aerospace_Engineering["Degree"] = "Bachelor of Technology"
Aerospace_Engineering["Branch"] = "Aerospace Engineering"
Aerospace_Engineering = Aerospace_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Chemical Engineering (4 Years, Bachelor of Technology) #16
Chemical_Engineering= df[df["Program"] == "Chemical Engineering (4 Years, Bachelor of Technology)"]
Chemical_Engineering["Duration"] = "4 Years"
Chemical_Engineering["Degree"] = "Bachelor of Technology"
Chemical_Engineering["Branch"] = "Chemical Engineering"
Chemical_Engineering = Chemical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Chemistry (4 Years, Bachelor of Science) #17
Chemistry  = df[df["Program"] == "Chemistry (4 Years, Bachelor of Science)"]
Chemistry["Duration"] = "4 Years"
Chemistry["Degree"] = "Bachelor of Science"
Chemistry["Branch"] = "Chemistry"
Chemistry = Chemistry.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Economics (4 Years, Bachelor of Science) #18
Economics = df[df["Program"] == "Economics (4 Years, Bachelor of Science)"]
Economics["Duration"] = "4 Years"
Economics["Degree"] = "Bachelor of Science"
Economics["Branch"] = "Economics"
Economics = Economics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Electrical Engineering with M.Tech. in Communications and Signal Processing (5 Years, Bachelor and Master of Technology (Dual Degree))
Electrical_Engineering_Dual_Communications_and_Signal_Processing = df[df["Program"] == "Electrical Engineering with M.Tech. in Communications and Signal Processing (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Electrical_Engineering_Dual_Communications_and_Signal_Processing["Duration"] = "5 Years"
Electrical_Engineering_Dual_Communications_and_Signal_Processing["Degree"] = "Bachelor and Master of Technology"
Electrical_Engineering_Dual_Communications_and_Signal_Processing["Branch"] = "Electrical Engineering in Communications and Signal_Processing"
Electrical_Engineering_Dual_Communications_and_Signal_Processing = Electrical_Engineering_Dual_Communications_and_Signal_Processing.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Electrical Engineering with M.Tech. in Microelectronics (5 Years, Bachelor and Master of Technology (Dual Degree)) #20
Electrical_Engineering_Dual_Microelectronics = df[df["Program"] == "Electrical Engineering with M.Tech. in Microelectronics (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Electrical_Engineering_Dual_Microelectronics["Duration"] = "5 Years"
Electrical_Engineering_Dual_Microelectronics["Degree"] = "Bachelor and Master of Technology"
Electrical_Engineering_Dual_Microelectronics["Branch"] = "Electrical Engineering in Microelectronics"
Electrical_Engineering_Dual_Microelectronics = Electrical_Engineering_Dual_Microelectronics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Energy Engineering with M.Tech. in Energy Systems Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) #21
Energy_Engineering_Dual_Energy_Systems = df[df["Program"] == "Energy Engineering with M.Tech. in Energy Systems Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Energy_Engineering_Dual_Energy_Systems["Duration"] = "5 Years"
Energy_Engineering_Dual_Energy_Systems["Degree"] = "Bachelor and Master of Technology"
Energy_Engineering_Dual_Energy_Systems["Branch"] = "Energy Engineering in Energy Systems"
Energy_Engineering_Dual_Energy_Systems = Energy_Engineering_Dual_Energy_Systems.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Engineering Physics (4 Years, Bachelor of Technology) #22
Engineering_Physics = df[df["Program"] == "Engineering Physics (4 Years, Bachelor of Technology)"]
Engineering_Physics["Duration"] = "4 Years"
Engineering_Physics["Degree"] = "Bachelor of Technology"
Engineering_Physics["Branch"] = "Engineering Physics"
Engineering_Physics = Engineering_Physics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Mechanical Engineering and M.Tech. in Computer Integrated Manufacturing (5 Years, Bachelor and Master of Technology (Dual Degree)) #23
Mechanical_Engineering_Dual_Computer_Integrated_Manufacturing = df[df["Program"] == "Mechanical Engineering and M.Tech. in Computer Integrated Manufacturing (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Mechanical_Engineering_Dual_Computer_Integrated_Manufacturing["Duration"] = "5 Years"
Mechanical_Engineering_Dual_Computer_Integrated_Manufacturing["Degree"] = "Bachelor and Master of Technology"
Mechanical_Engineering_Dual_Computer_Integrated_Manufacturing["Branch"] = "Mechanical Engineering in Computer Integrated Manufacturing"
Mechanical_Engineering_Dual_Computer_Integrated_Manufacturing = Mechanical_Engineering_Dual_Computer_Integrated_Manufacturing.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Metallurgical Engineering and Materials Science (4 Years, Bachelor of Technology) #24
Metallurgical_Engineering_and_Materials_Science = df[df["Program"] == "Metallurgical Engineering and Materials Science (4 Years, Bachelor of Technology)"]
Metallurgical_Engineering_and_Materials_Science["Duration"] = "4 Years"
Metallurgical_Engineering_and_Materials_Science["Degree"] = "Bachelor of Technology"
Metallurgical_Engineering_and_Materials_Science["Branch"] = "Metallurgical Engineering and Materials_Science"
Metallurgical_Engineering_and_Materials_Science = Metallurgical_Engineering_and_Materials_Science.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Metallurgical Engineering and Materials Science with M.Tech. in Ceramics and Composites (5 Years, Bachelor and Master of Technology (Dual Degree)) #25
Metallurgical_Engineering_and_Materials_Science_Dual_Ceramics_and_Composites = df[df["Program"] == "Metallurgical Engineering and Materials Science with M.Tech. in Ceramics and Composites (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Metallurgical_Engineering_and_Materials_Science_Dual_Ceramics_and_Composites["Duration"] = "5 Years"
Metallurgical_Engineering_and_Materials_Science_Dual_Ceramics_and_Composites["Degree"] = "Bachelor and Master of Technology"
Metallurgical_Engineering_and_Materials_Science_Dual_Ceramics_and_Composites["Branch"] = "Metallurgical Engineering and Materials_Science in Ceramics and Composites"
Metallurgical_Engineering_and_Materials_Science_Dual_Ceramics_and_Composites = Metallurgical_Engineering_and_Materials_Science_Dual_Ceramics_and_Composites.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Metallurgical Engineering and Materials Science with M.Tech. in Metallurgical Process Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) #26
Metallurgical_Engineering_and_Materials_Science_dual_Metallurgical_Process_Engineering = df[df["Program"] == "Metallurgical Engineering and Materials Science with M.Tech. in Metallurgical Process Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Metallurgical_Engineering_and_Materials_Science_dual_Metallurgical_Process_Engineering["Duration"] = "5 Years"
Metallurgical_Engineering_and_Materials_Science_dual_Metallurgical_Process_Engineering["Degree"] = "Bachelor and Master of Technology"
Metallurgical_Engineering_and_Materials_Science_dual_Metallurgical_Process_Engineering["Branch"] = "Metallurgical Engineering and Materials Science dual Metallurgical Process Engineering"
Metallurgical_Engineering_and_Materials_Science_dual_Metallurgical_Process_Engineering = Metallurgical_Engineering_and_Materials_Science_dual_Metallurgical_Process_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Biochemical Engineering and Biotechnology (5 Years, Bachelor and Master of Technology (Dual Degree)) #27
Biochemical_Engineering_and_Biotechnology = df[df["Program"] == "Biochemical Engineering and Biotechnology (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Biochemical_Engineering_and_Biotechnology["Duration"] = "5 Years"
Biochemical_Engineering_and_Biotechnology["Degree"] = "Bachelor and Master of Technology"
Biochemical_Engineering_and_Biotechnology["Branch"] = "Biochemical Engineering and Biotechnology"
Biochemical_Engineering_and_Biotechnology = Biochemical_Engineering_and_Biotechnology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Biotechnology and Biochemical Engineering (4 Years, Bachelor of Technology) #28
Biotechnology_and_Biochemical_Engineering = df[df["Program"] == "Biochemical Engineering and Biotechnology (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Biotechnology_and_Biochemical_Engineering["Duration"] = "4 Years"
Biotechnology_and_Biochemical_Engineering["Degree"] = "Bachelor of Technology"
Biotechnology_and_Biochemical_Engineering["Branch"] = "Biotechnology and Biochemical Engineering"
Biotechnology_and_Biochemical_Engineering = Biotechnology_and_Biochemical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Chemical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) #29
Chemical_Engineering= df[df["Program"] == "Chemical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Chemical_Engineering["Duration"] = "5 Years"
Chemical_Engineering["Degree"] = "Bachelor and Master of Technology"
Chemical_Engineering["Branch"] = "Biochemical Engineering and Biotechnology"
Chemical_Engineering = Chemical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Electrical Engineering (Power and Automation) (4 Years, Bachelor of Technology) #30
Electrical_Engineering_Powar_and_Automation= df[df["Program"] == "Electrical Engineering (Power and Automation) (4 Years, Bachelor of Technology)"]
Electrical_Engineering_Powar_and_Automation["Duration"] = "4 Years"
Electrical_Engineering_Powar_and_Automation["Degree"] = "Bachelor of Technology"
Electrical_Engineering_Powar_and_Automation["Branch"] = "Electrical Engineering Power and Automation"
Electrical_Engineering_Powar_and_Automation = Electrical_Engineering_Powar_and_Automation.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Mathematics and Computing (4 Years, Bachelor of Technology) #31
Mathematics_and_Computing= df[df["Program"] == "Mathematics and Computing (4 Years, Bachelor of Technology)"]
Mathematics_and_Computing["Duration"] = "4 Years"
Mathematics_and_Computing["Degree"] = "Bachelor of Technology"
Mathematics_and_Computing["Branch"] = "Mathematics and Computing"
Mathematics_and_Computing = Mathematics_and_Computing.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
  
# Mathematics and Computing (5 Years, Bachelor and Master of Technology (Dual Degree)) #32
Mathematics_and_Computing_Dual= df[df["Program"] == "Mathematics and Computing (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Mathematics_and_Computing_Dual["Duration"] = "5 Years"
Mathematics_and_Computing_Dual["Degree"] = "Bachelor and Master of Technology"
Mathematics_and_Computing_Dual["Branch"] = "Mathematics and Computing Dual Degree"
Mathematics_and_Computing_Dual = Mathematics_and_Computing_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Production and Industrial Engineering (4 Years, Bachelor of Technology) #33
Production_and_Industrial_Engineering= df[df["Program"] == "Production and Industrial Engineering (4 Years, Bachelor of Technology)"]
Production_and_Industrial_Engineering["Duration"] = "4 Years"
Production_and_Industrial_Engineering["Degree"] = "Bachelor of Technology"
Production_and_Industrial_Engineering["Branch"] = "Production and Industrial Engineering"
Production_and_Industrial_Engineering = Production_and_Industrial_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Textile Technology (4 Years, Bachelor of Technology)' #34    
Textile_Technology= df[df["Program"] == "Textile Technology (4 Years, Bachelor of Technology)"]
Textile_Technology["Duration"] = "4 Years"
Textile_Technology["Degree"] = "Bachelor of Technology"
Textile_Technology["Branch"] = "Textile Technology"
Textile_Technology = Textile_Technology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 

# 'Applied Geology (5 Years, Integrated Master of Technology)' #35
Applied_Geology= df[df["Program"] == "Applied Geology (5 Years, Integrated Master of Technology)"]
Applied_Geology["Duration"] = "5 Years"
Applied_Geology["Degree"] = "Bachelor and Master of Technology"
Applied_Geology["Branch"] = "Applied Geology"
Applied_Geology = Applied_Geology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Applied Geophysics (5 Years, Integrated Master of Technology)' #36
Applied_Geophysics= df[df["Program"] == "Applied Geophysics (5 Years, Integrated Master of Technology)"]
Applied_Geophysics["Duration"] = "5 Years"
Applied_Geophysics["Degree"] = "Bachelor and Master of Technology"
Applied_Geophysics["Branch"] = "Applied Geophysics"
Applied_Geophysics = Applied_Geophysics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Electronics and Instrumentation Engineering (4 Years, Bachelor of Technology)' #37
Electronics_and_Instrumentation_Engineering= df[df["Program"] == "Electronics and Instrumentation Engineering (4 Years, Bachelor of Technology)"]
Electronics_and_Instrumentation_Engineering["Duration"] = "4 Years"
Electronics_and_Instrumentation_Engineering["Degree"] = "Bachelor of Technology"
Electronics_and_Instrumentation_Engineering["Branch"] = "Electronics and Instrumentation Engineering"
Electronics_and_Instrumentation_Engineering = Electronics_and_Instrumentation_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Environmental Engineering (4 Years, Bachelor of Technology)' #38
Environmental_Engineering= df[df["Program"] == "Environmental Engineering (4 Years, Bachelor of Technology)"]
Environmental_Engineering["Duration"] = "4 Years"
Environmental_Engineering["Degree"] = "Bachelor of Technology"
Environmental_Engineering["Branch"] = "Environmental Engineering"
Environmental_Engineering = Environmental_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# 'Mathematics and Computing (5 Years, Integrated Master of Technology)' #39
Mathematics_and_Computing_Integrated = df[df["Program"] == "Mathematics and Computing (5 Years, Integrated Master of Technology)"]
Mathematics_and_Computing_Integrated["Duration"] = "5 Years"
Mathematics_and_Computing_Integrated["Degree"] = "Integrated Master of Technology"
Mathematics_and_Computing_Integrated["Branch"] = "Mathematics and Computing Integrated"
Mathematics_and_Computing_Integrated = Mathematics_and_Computing_Integrated.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Mineral Engineering (4 Years, Bachelor of Technology)' #40
Mineral_Engineering= df[df["Program"] == "Mineral Engineering (4 Years, Bachelor of Technology)"]
Mineral_Engineering["Duration"] = "4 Years"
Mineral_Engineering["Degree"] = "Bachelor of Technology"
Mineral_Engineering["Branch"] = "Mineral Engineering"
Mineral_Engineering = Mineral_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Mining Engineering (4 Years, Bachelor of Technology)'#41
Mining_Engineering= df[df["Program"] == "Mining Engineering (4 Years, Bachelor of Technology)"]
Mining_Engineering["Duration"] = "4 Years"
Mining_Engineering["Degree"] = "Bachelor of Technology"
Mining_Engineering["Branch"] = "Mining Engineering"
Mining_Engineering = Mining_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Mining Machinery Engineering (4 Years, Bachelor of Technology)'  #42
Mining_Machinery_Engineering= df[df["Program"] == "Mining Machinery Engineering (4 Years, Bachelor of Technology)"]
Mining_Machinery_Engineering["Duration"] = "4 Years"
Mining_Machinery_Engineering["Degree"] = "Bachelor of Technology"
Mining_Machinery_Engineering["Branch"] = "Mining Machinery Engineering"
Mining_Machinery_Engineering = Mining_Machinery_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Petroleum Engineering (4 Years, Bachelor of Technology)' #43
Petroleum_Engineering= df[df["Program"] == "Petroleum Engineering (4 Years, Bachelor of Technology)"]
Petroleum_Engineering["Duration"] = "4 Years"
Petroleum_Engineering["Degree"] = "Bachelor of Technology"
Petroleum_Engineering["Branch"] = "Petroleum Engineering"
Petroleum_Engineering = Petroleum_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Materials Science and Engineering (4 Years, Bachelor of Technology)' #44
Materials_Science_Engineering= df[df["Program"] == "Materials Science and Engineering (4 Years, Bachelor of Technology)"]
Materials_Science_Engineering["Duration"] = "4 Years"
Materials_Science_Engineering["Degree"] = "Bachelor of Technology"
Materials_Science_Engineering["Branch"] = "Materials Science and Engineering"
Materials_Science_Engineering = Materials_Science_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Bio Technology (4 Years, Bachelor of Technology)' #45
Bio_Technology= df[df["Program"] == "Bio Technology (4 Years, Bachelor of Technology)"]
Bio_Technology["Duration"] = "4 Years"
Bio_Technology["Degree"] = "Bachelor of Technology"
Bio_Technology["Branch"] = "Bio Technology"
Bio_Technology = Bio_Technology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Chemical Science and Technology (4 Years, Bachelor of Technology)' #46

Chemical_Science_and_Technology= df[df["Program"] == "Chemical Science and Technology (4 Years, Bachelor of Technology)"]
Chemical_Science_and_Technology["Duration"] = "4 Years"
Chemical_Science_and_Technology["Degree"] = "Bachelor of Technology"
Chemical_Science_and_Technology["Branch"] = "Chemical Science and Technology"
Chemical_Science_and_Technology = Chemical_Science_and_Technology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 

# 'Electronics and Electrical Engineering (4 Years, Bachelor of Technology)' #47

Electronics_and_Electrical_Engineering= df[df["Program"] == "Electronics and Electrical Engineering (4 Years, Bachelor of Technology)"]
Electronics_and_Electrical_Engineering["Duration"] = "4 Years"
Electronics_and_Electrical_Engineering["Degree"] = "Bachelor of Technology"
Electronics_and_Electrical_Engineering["Branch"] = "Electronics and Electrical Engineering"
Electronics_and_Electrical_Engineering = Electronics_and_Electrical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Engineering Science (4 Years, Bachelor of Technology)' #48
Engineering_Science= df[df["Program"] == "Engineering Science (4 Years, Bachelor of Technology)"]
Engineering_Science["Duration"] = "4 Years"
Engineering_Science["Degree"] = "Bachelor of Technology"
Engineering_Science["Branch"] = "Engineering Science"
Engineering_Science = Engineering_Science.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 

#  'Materials Science and Metallurgical Engineering (4 Years, Bachelor of Technology)' #49
Materials_Science_and_Metallurgical_Engineering= df[df["Program"] == "Materials Science and Metallurgical Engineering (4 Years, Bachelor of Technology)"]
Materials_Science_and_Metallurgical_Engineering["Duration"] = "4 Years"
Materials_Science_and_Metallurgical_Engineering["Degree"] = "Bachelor of Technology"
Materials_Science_and_Metallurgical_Engineering["Branch"] = "Materials Science and Metallurgical Engineering"
Materials_Science_and_Metallurgical_Engineering = Materials_Science_and_Metallurgical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 


# 'Biological Sciences and Bioengineering (4 Years, Bachelor of Technology)'#50

Biological_Sciences_and_Bioengineering= df[df["Program"] == "Biological Sciences and Bioengineering (4 Years, Bachelor of Technology)"]
Biological_Sciences_and_Bioengineering["Duration"] = "4 Years"
Biological_Sciences_and_Bioengineering["Degree"] = "Bachelor of Technology"
Biological_Sciences_and_Bioengineering["Branch"] = "Biological Sciences and Bioengineering"
Biological_Sciences_and_Bioengineering = Biological_Sciences_and_Bioengineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Earth Sciences (4 Years, Bachelor of Science)'#51
Earth_Engineering= df[df["Program"] == "Earth Sciences (4 Years, Bachelor of Science)"]
Earth_Engineering["Duration"] = "4 Years"
Earth_Engineering["Degree"] = "Bachelor of Technology"
Earth_Engineering["Branch"] = "Earth Engineering"
Earth_Engineering = Earth_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
#'Mathematics and Scientific Computing (4 Years, Bachelor of Science)'#52
Mathematics_and_Scientific_Computing= df[df["Program"] == "Mathematics and Scientific Computing (4 Years, Bachelor of Science)"]
Mathematics_and_Scientific_Computing["Duration"] = "4 Years"
Mathematics_and_Scientific_Computing["Degree"] = "Bachelor of Science"
Mathematics_and_Scientific_Computing["Branch"] = "Mathematics and Scientific Computing"
Mathematics_and_Scientific_Computing = Mathematics_and_Scientific_Computing.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# 'Physics (4 Years, Bachelor of Science)'#53
Physics= df[df["Program"] == "Physics (4 Years, Bachelor of Science)"]
Physics["Duration"] = "4 Years"
Physics["Degree"] = "Bachelor of Science"
Physics["Branch"] = "Physics"
Physics = Physics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 


# 'Aerospace Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))' #54
Aerospace_Engineering_Dual = df[df["Program"] == "Aerospace Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Aerospace_Engineering_Dual["Duration"] = "5 Years"
Aerospace_Engineering_Dual["Degree"] = "Bachelor and Master of Science"
Aerospace_Engineering_Dual["Branch"] = "Aerospace Engineering Dual"
Aerospace_Engineering_Dual = Aerospace_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Agricultural and Food Engineering (4 Years, Bachelor of Technology)'#55
Agricultural_and_Food_Engineering= df[df["Program"] == "Agricultural and Food Engineering (4 Years, Bachelor of Technology)"]
Agricultural_and_Food_Engineering["Duration"] = "4 Years"
Agricultural_and_Food_Engineering["Degree"] = "Bachelor of Technology"
Agricultural_and_Food_Engineering["Branch"] = "Agricultural and Food Engineering"
Agricultural_and_Food_Engineering = Agricultural_and_Food_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 

# 'Agricultural and Food Engineering with M.Tech. in any of the listed specializations (5 Years, Bachelor and Master of Technology (Dual Degree)) #56
Agricultural_and_Food_Engineering_Dual_Any_Specialization = df[df["Program"] == "Agricultural and Food Engineering with M.Tech. in any of the listed specializations (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Agricultural_and_Food_Engineering_Dual_Any_Specialization["Duration"] = "5 Years"
Agricultural_and_Food_Engineering_Dual_Any_Specialization["Degree"] = "Bachelor and Master of Technology"
Agricultural_and_Food_Engineering_Dual_Any_Specialization["Branch"] = "Agricultural and Food Engineering with M.Tech. in any of the listed specializations"
Agricultural_and_Food_Engineering_Dual_Any_Specialization = Agricultural_and_Food_Engineering_Dual_Any_Specialization.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Applied Geology (5 Years, Integrated Master of Science)' #57


# Architecture (5 Years, Bachelor of Architecture) #58
Architecture = df[df["Program"] == "Architecture (5 Years, Bachelor of Architecture)"]
Architecture["Duration"] = "5 Years"
Architecture["Degree"] = "Bachelor of Architecture"
Architecture["Branch"] = "Architecture"
Architecture = Architecture.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Biotechnology and Biochemical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))' #59

Biotechnology_and_Biochemical_Engineering_Dual = df[df["Program"] == "Biotechnology and Biochemical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Biotechnology_and_Biochemical_Engineering_Dual["Duration"] = "5 Years"
Biotechnology_and_Biochemical_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Biotechnology_and_Biochemical_Engineering_Dual["Branch"] = "Biotechnology and Biochemical Engineering"
Biotechnology_and_Biochemical_Engineering_Dual = Biotechnology_and_Biochemical_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Chemistry (5 Years, Integrated Master of Science)' #60

Chemistry_Integrated = df[df["Program"] == "Chemistry (5 Years, Integrated Master of Science)"]
Chemistry_Integrated["Duration"] = "5 Years"
Chemistry_Integrated["Degree"] = "Integrated Master of Science"
Chemistry_Integrated["Branch"] = "Chemistry"
Chemistry_Integrated = Chemistry_Integrated.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# 'Civil Engineering with any of the listed specialization (5 Years, Bachelor and Master of Technology (Dual Degree))' #61
Civil_Engineering_Dual_Any_Specialization= df[df["Program"] == "Civil Engineering with any of the listed specialization (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Civil_Engineering_Dual_Any_Specialization["Duration"] = "5 Years"
Civil_Engineering_Dual_Any_Specialization["Degree"] = "Bachelor and Master of Technology"
Civil_Engineering_Dual_Any_Specialization["Branch"] = "Civil Engineering"
Civil_Engineering_Dual_Any_Specialization = Civil_Engineering_Dual_Any_Specialization.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Economics (5 Years, Integrated Master of Science)'#62
Economics_Integrated = df[df["Program"] == "Economics (5 Years, Integrated Master of Science)"]
Economics_Integrated["Duration"] = "5 Years"
Economics_Integrated["Degree"] = "Integrated Master of Science"
Economics_Integrated["Branch"] = "Economics"
Economics_Integrated = Economics_Integrated.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
#'Electrical Engineering with M.Tech. in any of the listed specializations (5 Years, Bachelor and Master of Technology (Dual Degree))'#63
Electrical_Engineering_Dual_Any_Specialization = df[df["Program"] == "Electrical Engineering with M.Tech. in any of the listed specializations (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Electrical_Engineering_Dual_Any_Specialization["Duration"] = "5 Years"
Electrical_Engineering_Dual_Any_Specialization["Degree"] = "Bachelor and Master of Technology"
Electrical_Engineering_Dual_Any_Specialization["Branch"] = "Electrical Engineering "
Electrical_Engineering_Dual_Any_Specialization = Electrical_Engineering_Dual_Any_Specialization.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Electronics and Electrical Communication Engineering (4 Years, Bachelor of Technology)' #64

Electronics_and_Electrical_Communication_Engineering= df[df["Program"] == "Electronics and Electrical Communication Engineering (4 Years, Bachelor of Technology)"]
Electronics_and_Electrical_Communication_Engineering["Duration"] = "4 Years"
Electronics_and_Electrical_Communication_Engineering["Degree"] = "Bachelor of Technology"
Electronics_and_Electrical_Communication_Engineering["Branch"] = "Electronics and Electrical Communication Engineering"
Electronics_and_Electrical_Communication_Engineering = Electronics_and_Electrical_Communication_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Electronics and Electrical Communication Engineering with M.Tech. in any of the listed specializations (5 Years, Bachelor and Master of Technology (Dual Degree))' # 65

Electronics_and_Electrical_Communication_Engineering_Dual_Any_Specialization= df[df["Program"] == "Electronics and Electrical Communication Engineering with M.Tech. in any of the listed specializations (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Electronics_and_Electrical_Communication_Engineering_Dual_Any_Specialization["Duration"] = "5 Years"
Electronics_and_Electrical_Communication_Engineering_Dual_Any_Specialization["Degree"] = "Bachelor and Master of Technology"
Electronics_and_Electrical_Communication_Engineering_Dual_Any_Specialization["Branch"] = "Electronics and Electrical Communication Engineering"
Electronics_and_Electrical_Communication_Engineering_Dual_Any_Specialization = Electronics_and_Electrical_Communication_Engineering_Dual_Any_Specialization.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Exploration Geophysics (5 Years, Integrated Master of Science)' #66
Exploration_Geophysics= df[df["Program"] == "Exploration Geophysics (5 Years, Integrated Master of Science)"]
Exploration_Geophysics["Duration"] = "5 Years"
Exploration_Geophysics["Degree"] = "Integrated Master of Science"
Exploration_Geophysics["Branch"] = "Exploration Geophysics"
Exploration_Geophysics = Exploration_Geophysics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Industrial and Systems Engineering (4 Years, Bachelor of Technology)' #67
Industrial_and_Systems_Engineering= df[df["Program"] == "Industrial and Systems Engineering (4 Years, Bachelor of Technology)"]
Industrial_and_Systems_Engineering["Duration"] = "4 Years"
Industrial_and_Systems_Engineering["Degree"] = "Bachelor of Technology"
Industrial_and_Systems_Engineering["Branch"] = "Industrial and Systems Engineering"
Industrial_and_Systems_Engineering = Industrial_and_Systems_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# 'Industrial and Systems Engineering with M.Tech. in Industrial and Systems Engineering and Management (5 Years, Bachelor and Master of Technology (Dual Degree))'#68
Industrial_and_Systems_Engineering_dual_Industrial_and_Systems_Engineering_and_Management= df[df["Program"] == "Industrial and Systems Engineering with M.Tech. in Industrial and Systems Engineering and Management (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Industrial_and_Systems_Engineering_dual_Industrial_and_Systems_Engineering_and_Management["Duration"] = "5 Years"
Industrial_and_Systems_Engineering_dual_Industrial_and_Systems_Engineering_and_Management["Degree"] = "Bachelor and Master of Technology"
Industrial_and_Systems_Engineering_dual_Industrial_and_Systems_Engineering_and_Management["Branch"] = "Industrial and Systems Engineering dual Industrial and Systems Engineering and Management"
Industrial_and_Systems_Engineering_dual_Industrial_and_Systems_Engineering_and_Management = Industrial_and_Systems_Engineering_dual_Industrial_and_Systems_Engineering_and_Management.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Instrumentation Engineering (4 Years, Bachelor of Technology)'#69
Instrumentation_Engineering= df[df["Program"] == "Instrumentation Engineering (4 Years, Bachelor of Technology)"]
Instrumentation_Engineering["Duration"] = "4 Years"
Instrumentation_Engineering["Degree"] = "Bachelor of Technology"
Instrumentation_Engineering["Branch"] = "Instrumentation Engineering"
Instrumentation_Engineering = Instrumentation_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Manufacturing Science and Engineering (4 Years, Bachelor of Technology)' #70
Manufacturing_Science_and_Engineering= df[df["Program"] == "Manufacturing Science and Engineering (4 Years, Bachelor of Technology)"]
Manufacturing_Science_and_Engineering["Duration"] = "4 Years"
Manufacturing_Science_and_Engineering["Degree"] = "Bachelor of Technology"
Manufacturing_Science_and_Engineering["Branch"] = "Manufacturing Science and Engineering"
Manufacturing_Science_and_Engineering = Manufacturing_Science_and_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Manufacturing Science and Engineering with M.Tech. in Industrial and Systems Engineering and Management (5 Years, Bachelor and Master of Technology (Dual Degree))' #71

Manufacturing_Science_and_Engineering_Dual_Industrial_and_Systems_Engineering_and_Management= df[df["Program"] == "Manufacturing Science and Engineering with M.Tech. in Industrial and Systems Engineering and Management (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Manufacturing_Science_and_Engineering_Dual_Industrial_and_Systems_Engineering_and_Management["Duration"] = "5 Years"
Manufacturing_Science_and_Engineering_Dual_Industrial_and_Systems_Engineering_and_Management["Degree"] = "Bachelor and Master of Technology"
Manufacturing_Science_and_Engineering_Dual_Industrial_and_Systems_Engineering_and_Management["Branch"] = "Manufacturing Science and Engineering"
Manufacturing_Science_and_Engineering_Dual_Industrial_and_Systems_Engineering_and_Management = Manufacturing_Science_and_Engineering_Dual_Industrial_and_Systems_Engineering_and_Management.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 

# 'Mathematics and Computing (5 Years, Integrated Master of Science)' #72
Mathematics_and_Computing_Integrated= df[df["Program"] == "Mathematics and Computing (5 Years, Integrated Master of Science)"]
Mathematics_and_Computing_Integrated["Duration"] = "5 Years"
Mathematics_and_Computing_Integrated["Degree"] = "Integrated Master of Science"
Mathematics_and_Computing_Integrated["Branch"] = "Mathematics and Computing"
Mathematics_and_Computing_Integrated = Mathematics_and_Computing_Integrated.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Mechanical Engineering with M.Tech. in any of the listed specializations (5 Years, Bachelor and Master of Technology (Dual Degree))'# 73
Mechanical_Engineering_Dual_Any_Specialization = df[df["Program"] == "Mechanical Engineering with M.Tech. in any of the listed specializations (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Mechanical_Engineering_Dual_Any_Specialization["Duration"] = "5 Years"
Mechanical_Engineering_Dual_Any_Specialization["Degree"] = "Bachelor and Master of Technology"
Mechanical_Engineering_Dual_Any_Specialization["Branch"] = "Mechanical Engineering"
Mechanical_Engineering_Dual_Any_Specialization = Mechanical_Engineering_Dual_Any_Specialization.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
#'Metallurgical and Materials Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))' #74
Metallurgical_and_Materials_Engineering_Dual= df[df["Program"] == "Metallurgical and Materials Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Metallurgical_and_Materials_Engineering_Dual["Duration"] = "5 Years"
Metallurgical_and_Materials_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Metallurgical_and_Materials_Engineering_Dual["Branch"] = "Metallurgical and Materials Engineering"
Metallurgical_and_Materials_Engineering_Dual = Metallurgical_and_Materials_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Mining Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))' #75
Mining_Engineering_Dual= df[df["Program"] == "Mining Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Mining_Engineering_Dual["Duration"] = "5 Years"
Mining_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Mining_Engineering_Dual["Branch"] = "Mining Engineering"
Mining_Engineering_Dual = Mining_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 

# 'Mining Safety Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))' #76
Mining_Safety_Engineering_Dual= df[df["Program"] == "Mining Safety Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Mining_Safety_Engineering_Dual["Duration"] = "5 Years"
Mining_Safety_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Mining_Safety_Engineering_Dual["Branch"] = "Mining Safety Engineering"
Mining_Safety_Engineering_Dual = Mining_Safety_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Ocean Engineering and Naval Architecture (4 Years, Bachelor of Technology)' #77
Ocean_Engineering_and_Naval_Architecture= df[df["Program"] == "Ocean Engineering and Naval Architecture (4 Years, Bachelor of Technology)"]
Ocean_Engineering_and_Naval_Architecture["Duration"] = "4 Years"
Ocean_Engineering_and_Naval_Architecture["Degree"] = "Bachelor of Technology"
Ocean_Engineering_and_Naval_Architecture["Branch"] = "Ocean Engineering and Naval Architecture"
Ocean_Engineering_and_Naval_Architecture = Ocean_Engineering_and_Naval_Architecture.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Ocean Engineering and Naval Architecture (5 Years, Bachelor and Master of Technology (Dual Degree))' #78
Ocean_Engineering_and_Naval_Architecture_Dual= df[df["Program"] == "Ocean Engineering and Naval Architecture (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Ocean_Engineering_and_Naval_Architecture_Dual["Duration"] = "5 Years"
Ocean_Engineering_and_Naval_Architecture_Dual["Degree"] = "Bachelor and Master of Technology"
Ocean_Engineering_and_Naval_Architecture_Dual["Branch"] = "Ocean Engineering and Naval Architecture"
Ocean_Engineering_and_Naval_Architecture_Dual = Ocean_Engineering_and_Naval_Architecture_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Physics (5 Years, Integrated Master of Science)' #79
Physics_Integrated= df[df["Program"] == "Physics (5 Years, Integrated Master of Science)"]
Physics_Integrated["Duration"] = "5 Years"
Physics_Integrated["Degree"] = "Integrated Master of Science"
Physics_Integrated["Branch"] = "Physics"
Physics_Integrated = Physics_Integrated.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# 'Quality Engineering Design and Manufacturing (5 Years, Bachelor and Master of Technology (Dual Degree))'#80
Quality_Engineering_Design_and_Manufacturing_Dual= df[df["Program"] == "Quality Engineering Design and Manufacturing (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Quality_Engineering_Design_and_Manufacturing_Dual["Duration"] = "5 Years"
Quality_Engineering_Design_and_Manufacturing_Dual["Degree"] = "Bachelor and Master of Technology"
Quality_Engineering_Design_and_Manufacturing_Dual["Branch"] = "Quality Engineering Design and Manufacturing"
Quality_Engineering_Design_and_Manufacturing_Dual = Quality_Engineering_Design_and_Manufacturing_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Biological Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))' #81
Biological_Engineering_Dual= df[df["Program"] == "Biological Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Biological_Engineering_Dual["Duration"] = "5 Years"
Biological_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Biological_Engineering_Dual["Branch"] = "Biological Engineering"
Biological_Engineering_Dual = Biological_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Biological Sciences (5 Years, Bachelor of Science and Master of Science (Dual Degree))'#82
Biological_Sciences_Dual= df[df["Program"] == "Biological Sciences (5 Years, Bachelor of Science and Master of Science (Dual Degree))"]
Biological_Sciences_Dual["Duration"] = "5 Years"
Biological_Sciences_Dual["Degree"] = "Bachelor and Master of Technology"
Biological_Sciences_Dual["Branch"] = "Biological Sciences"
Biological_Sciences_Dual = Biological_Sciences_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Civil Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))' #83
Civil_Engineering_Dual= df[df["Program"] == "Civil Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Civil_Engineering_Dual["Duration"] = "5 Years"
Civil_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Civil_Engineering_Dual["Branch"] = "Civil Engineering"
Civil_Engineering_Dual = Civil_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
#'Electrical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))'#84
Electrical_Engineering_Dual= df[df["Program"] == "Electrical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Electrical_Engineering_Dual["Duration"] = "5 Years"
Electrical_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Electrical_Engineering_Dual["Branch"] = "Electrical Engineering"
Electrical_Engineering_Dual = Electrical_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

#'Engineering Design (5 Years, Bachelor and Master of Technology (Dual Degree))'#85
Engineering_Design_Dual= df[df["Program"] == "Engineering Design (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Engineering_Design_Dual["Degree"] = "Bachelor and Master of Technology"
Engineering_Design_Dual["Branch"] = "Engineering Design"
Engineering_Design_Dual = Engineering_Design_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# 'Mechanical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))' #86
Mechanical_Engineering_Dual = df[df["Program"] == "Mechanical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Mechanical_Engineering_Dual["Duration"] = "5 Years"
Mechanical_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Mechanical_Engineering_Dual["Branch"] = "Mechanical Engineering"
Mechanical_Engineering_Dual = Mechanical_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 


# Naval Architecture and Ocean Engineering (4 Years, Bachelor of Technology) #87
Naval_Architecture_and_Ocean_Engineering = df[df["Program"] == "Naval Architecture and Ocean Engineering (4 Years, Bachelor of Technology)"]
Naval_Architecture_and_Ocean_Engineering["Duration"] = "4 Years"
Naval_Architecture_and_Ocean_Engineering["Degree"] = "Bachelor of Technology"
Naval_Architecture_and_Ocean_Engineering["Branch"] = "Naval Architecture and Ocean Engineering"
Naval_Architecture_and_Ocean_Engineering = Naval_Architecture_and_Ocean_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 

#'Naval Architecture and Ocean Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))'#88
Naval_Architecture_and_Ocean_Engineering_Dual = df[df["Program"] == "Naval Architecture and Ocean Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Naval_Architecture_and_Ocean_Engineering_Dual["Duration"] = "5 Years"
Naval_Architecture_and_Ocean_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Naval_Architecture_and_Ocean_Engineering_Dual["Branch"] = "Naval Architecture and Ocean Engineering"
Naval_Architecture_and_Ocean_Engineering_Dual = Naval_Architecture_and_Ocean_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Physics (5 Years, Bachelor of Science and Master of Science (Dual Degree))' #89
Physics_Dual = df[df["Program"] == "Physics (5 Years, Bachelor of Science and Master of Science (Dual Degree))"]
Physics_Dual["Duration"] = "5 Years"
Physics_Dual["Degree"] = "Bachelor and Master of Technology"
Physics_Dual["Branch"] =  "Physics"
Physics_Dual = Physics_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Applied Mathematics (5 Years, Integrated Master of Science)' #90
Applied_Mathematics = df[df["Program"] == "Applied Mathematics (5 Years, Integrated Master of Science)"]
Applied_Mathematics["Duration"] = "5 Years"
Applied_Mathematics["Degree"] = "Integrated Master of Science"
Applied_Mathematics["Branch"] =  "Applied Mathematics"
Applied_Mathematics = Applied_Mathematics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

#'Geological Technology (5 Years, Integrated Master of Technology)' #91
Geological_Technology_Integrated = df[df["Program"] == "Geological Technology (5 Years, Integrated Master of Technology)"]
Geological_Technology_Integrated["Duration"] = "5 Years"
Geological_Technology_Integrated["Degree"] = "Integrated Master of Science"
Geological_Technology_Integrated["Branch"] =  "Geological Technology"
Geological_Technology_Integrated = Geological_Technology_Integrated.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Geophysical Technology (5 Years, Integrated Master of Technology)' #92
Geophysical_Technology_Integrated = df[df["Program"] == "Geophysical Technology (5 Years, Integrated Master of Technology)"]
Geophysical_Technology_Integrated["Duration"] = "5 Years"
Geophysical_Technology_Integrated["Degree"] = "Integrated Master of Science"
Geophysical_Technology_Integrated["Branch"] =  "Geophysical Technology"
Geophysical_Technology_Integrated = Geophysical_Technology_Integrated.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# 'Polymer Science and Engineering (4 Years, Bachelor of Technology)' #93
Polymer_Science_and_Engineering = df[df["Program"] == "Polymer Science and Engineering (4 Years, Bachelor of Technology)"]
Polymer_Science_and_Engineering["Duration"] = "4 Years"
Polymer_Science_and_Engineering["Degree"] = "Bachelor of Technology"
Polymer_Science_and_Engineering["Branch"] =  "Polymer Science and Engineering"
Polymer_Science_and_Engineering = Polymer_Science_and_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Biochemical Engineering with M.Tech. in Biochemical Engineering and Biotechnology (5 Years, Bachelor and Master of Technology (Dual Degree))#94
Biochemical_Engineering_Dual_Biochemical_Engineering_and_Biotechnology = df[df["Program"] == "Biochemical Engineering with M.Tech. in Biochemical Engineering and Biotechnology (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Biochemical_Engineering_Dual_Biochemical_Engineering_and_Biotechnology["Duration"] = "5 Years"
Biochemical_Engineering_Dual_Biochemical_Engineering_and_Biotechnology["Degree"] = "Bachelor ans Master of Technology"
Biochemical_Engineering_Dual_Biochemical_Engineering_and_Biotechnology["Branch"] =  "Biochemical Engineering Dual Biochemical Engineering and Biotechnology"
Biochemical_Engineering_Dual_Biochemical_Engineering_and_Biotechnology = Biochemical_Engineering_Dual_Biochemical_Engineering_and_Biotechnology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Bioengineering with M.Tech in Biomedical Technology (5 Years, Bachelor and Master of Technology (Dual Degree))# 95
Bioengineering_Dual_Biomedical_Technology = df[df["Program"] == "Bioengineering with M.Tech in Biomedical Technology (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Bioengineering_Dual_Biomedical_Technology["Duration"] = "5 Years"
Bioengineering_Dual_Biomedical_Technology["Degree"] = "Bachelor ans Master of Technology"
Bioengineering_Dual_Biomedical_Technology["Branch"] =  "Bioengineering and Biomedical Technology"
Bioengineering_Dual_Biomedical_Technology = Bioengineering_Dual_Biomedical_Technology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Ceramic Engineering (4 Years, Bachelor of Technology))# 96
Ceramic_Engineering = df[df["Program"] == "Ceramic Engineering (4 Years, Bachelor of Technology)"]
Ceramic_Engineering["Duration"] = "4 Years"
Ceramic_Engineering["Degree"] = "Bachelor of Technology"
Ceramic_Engineering["Branch"] =  "Ceramic Engineering"
Ceramic_Engineering = Ceramic_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Ceramic Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))# 97
Ceramic_Engineering_Dual = df[df["Program"] == "Ceramic Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Ceramic_Engineering_Dual["Duration"] = "5 Years"
Ceramic_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Ceramic_Engineering_Dual["Branch"] =  "Ceramic Engineering"
Ceramic_Engineering_Dual = Ceramic_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Electrical Engineering with M.Tech. in Power Electronics (5 Years, Bachelor and Master of Technology (Dual Degree))# 98
Electrical_Engineering_Dual_Power_Electronics = df[df["Program"] == "Electrical Engineering with M.Tech. in Power Electronics (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Electrical_Engineering_Dual_Power_Electronics["Duration"] = "4 Years"
Electrical_Engineering_Dual_Power_Electronics["Degree"] = "Bachelor and Master of Technology"
Electrical_Engineering_Dual_Power_Electronics["Branch"] =  "Electrical Engineering Dual Power Electronics"
Electrical_Engineering_Dual_Power_Electronics = Electrical_Engineering_Dual_Power_Electronics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Electronics Engineering (4 Years, Bachelor of Technology)# 99
Electronics_Engineering = df[df["Program"] == "Electronics Engineering (4 Years, Bachelor of Technology)"]
Electronics_Engineering["Duration"] = "4 Years"
Electronics_Engineering["Degree"] = "Bachelor of Technology"
Electronics_Engineering["Branch"] =  "Electronics Engineering"
Electronics_Engineering = Electronics_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Engineering Physics (5 Years, Bachelor and Master of Technology (Dual Degree)) # 100
Engineering_Physics_Dual = df[df["Program"] == "Engineering Physics (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Engineering_Physics_Dual["Duration"] = "5 Years"
Engineering_Physics_Dual["Degree"] = "Bachelor and Master of Technology"
Engineering_Physics_Dual["Branch"] =  "Electronics Engineering"
Engineering_Physics_Dual = Engineering_Physics_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Industrial Chemistry (5 Years, Bachelor and Master of Technology (Dual Degree))# 101
Industrial_Chemistry_Dual = df[df["Program"] == "Industrial Chemistry (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Industrial_Chemistry_Dual["Duration"] = "5 Years"
Industrial_Chemistry_Dual["Degree"] = "Bachelor and Master of Technology"
Industrial_Chemistry_Dual["Branch"] =  "Industrial Chemistry"
Industrial_Chemistry_Dual = Industrial_Chemistry_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Materials Science and Technology (5 Years, Bachelor and Master of Technology (Dual Degree)) # 102
Materials_Science_and_Technology_Dual = df[df["Program"] == "Materials Science and Technology (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Materials_Science_and_Technology_Dual["Duration"] = "5 Years"
Materials_Science_and_Technology_Dual["Degree"] = "Bachelor and Master of Technology"
Materials_Science_and_Technology_Dual["Branch"] =  "Materials Science and Technology"
Materials_Science_and_Technology_Dual = Materials_Science_and_Technology_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Metallurgical Engineering (4 Years, Bachelor of Technology) # 103
Metallurgical_Engineering = df[df["Program"] == "Metallurgical Engineering (4 Years, Bachelor of Technology)"]
Metallurgical_Engineering["Duration"] = "4 Years"
Metallurgical_Engineering["Degree"] = "Bachelor of Technology"
Metallurgical_Engineering["Branch"] =  "Metallurgical Engineering"
Metallurgical_Engineering = Metallurgical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Metallurgical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) # 104
Metallurgical_Engineering_Dual = df[df["Program"] == "Metallurgical Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Metallurgical_Engineering_Dual["Duration"] = "5 Years"
Metallurgical_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Metallurgical_Engineering_Dual["Branch"] =  "Metallurgical Engineering"
Metallurgical_Engineering_Dual = Metallurgical_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Pharmaceutical Engineering & Technology (4 Years, Bachelor of Technology) # 105
Pharmaceutical_Engineering_and_Technology = df[df["Program"] == "Pharmaceutical Engineering & Technology (4 Years, Bachelor of Technology)"]
Pharmaceutical_Engineering_and_Technology["Duration"] = "4 Years"
Pharmaceutical_Engineering_and_Technology["Degree"] = "Bachelor of Technology"
Pharmaceutical_Engineering_and_Technology["Branch"] =  "Pharmaceutical Engineering and Technology"
Pharmaceutical_Engineering_and_Technology = Pharmaceutical_Engineering_and_Technology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Pharmaceutical Engineering & Technology (5 Years, Bachelor and Master of Technology (Dual Degree)) # 106
Pharmaceutical_Engineering_and_Technology_Dual = df[df["Program"] == "Pharmaceutical Engineering & Technology (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Pharmaceutical_Engineering_and_Technology_Dual["Duration"] = "5 Years"
Pharmaceutical_Engineering_and_Technology_Dual["Degree"] = "Bachelor and Master of Technology"
Pharmaceutical_Engineering_and_Technology_Dual["Branch"] =  "Pharmaceutical Engineering and Technology"
Pharmaceutical_Engineering_and_Technology_Dual = Pharmaceutical_Engineering_and_Technology_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# BS in Mathematics (4 Years, Bachelor of Science)# 107
BS_in_Mathematics = df[df["Program"] == "BS in Mathematics (4 Years, Bachelor of Science)"]
BS_in_Mathematics["Duration"] = "4 Years"
BS_in_Mathematics["Degree"] = "Bachelor of Technology"
BS_in_Mathematics["Branch"] =  "BS in Mathematics"
BS_in_Mathematics = BS_in_Mathematics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Environmental Science and Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) # 108
Environmental_Science_and_Engineering_Dual = df[df["Program"] == "Environmental Science and Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Environmental_Science_and_Engineering_Dual["Duration"] = "5 Years"
Environmental_Science_and_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Environmental_Science_and_Engineering_Dual["Branch"] =  "Environmental Science and Engineering"
Environmental_Science_and_Engineering_Dual = Environmental_Science_and_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Metallurgical Engineering & Materials Science (5 Years, Bachelor and Master of Technology (Dual Degree)) # 109
Metallurgical_Engineering_and_Materials_Science_Dual  = df[df["Program"] == "Metallurgical Engineering & Materials Science (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Metallurgical_Engineering_and_Materials_Science_Dual["Duration"] = "5 Years"
Metallurgical_Engineering_and_Materials_Science_Dual["Degree"] = "Bachelor and Master of Technology"
Metallurgical_Engineering_and_Materials_Science_Dual["Branch"] =  "Metallurgical Engineering and Materials Science"
Metallurgical_Engineering_and_Materials_Science_Dual = Metallurgical_Engineering_and_Materials_Science_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Artificial Intelligence (4 Years, Bachelor of Technology) # 110
Artificial_Intelligence  = df[df["Program"] == "Artificial Intelligence (4 Years, Bachelor of Technology)"]
Artificial_Intelligence["Duration"] = "5 Years"
Artificial_Intelligence["Degree"] = "Bachelor and Master of Technology"
Artificial_Intelligence["Branch"] =  "Artificial Intelligence"
Artificial_Intelligence = Artificial_Intelligence.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Bio Engineering (4 Years, Bachelor of Technology) # 111
Bio_Engineering  = df[df["Program"] == "Bio Engineering (4 Years, Bachelor of Technology)"]
Bio_Engineering["Duration"] = "4 Years"
Bio_Engineering["Degree"] = "Bachelor of Technology"
Bio_Engineering["Branch"] =  "Bio Engineering"
Bio_Engineering = Bio_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Bio Engineering (5 Years, Bachelor and Master of Technology (Dual Degree)) # 112
Bio_Engineering_Dual  = df[df["Program"] == "Bio Engineering (5 Years, Bachelor and Master of Technology (Dual Degree))"]
Bio_Engineering_Dual["Duration"] = "5 Years"
Bio_Engineering_Dual["Degree"] = "Bachelor and Master of Technology"
Bio_Engineering_Dual["Branch"] =  "Bio Engineering"
Bio_Engineering_Dual = Bio_Engineering_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Data Science and Engineering (4 Years, Bachelor of Technology) # 113
Data_Science_and_Engineering  = df[df["Program"] == "Data Science and Engineering (4 Years, Bachelor of Technology)"]
Data_Science_and_Engineering["Duration"] = "4 Years"
Data_Science_and_Engineering["Degree"] = "Bachelor of Technology"
Data_Science_and_Engineering["Branch"] =  "Data Science and Engineering"
Data_Science_and_Engineering = Data_Science_and_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Data Science and Artificial Intelligence (4 Years, Bachelor of Technology) # 114
Data_Science_and_Artificial_Intelligence  = df[df["Program"] == "Data Science and Artificial Intelligence (4 Years, Bachelor of Technology)"]
Data_Science_and_Artificial_Intelligence["Duration"] = "4 Years"
Data_Science_and_Artificial_Intelligence["Degree"] = "Bachelor of Technology"
Data_Science_and_Artificial_Intelligence["Branch"] =  "Data Science and Artificial Intelligence"
Data_Science_and_Artificial_Intelligence = Data_Science_and_Artificial_Intelligence.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Energy Engineering (4 Years, Bachelor of Technology) # 115
Energy_Engineering  = df[df["Program"] == "Energy Engineering (4 Years, Bachelor of Technology)"]
Energy_Engineering["Duration"] = "4 Years"
Energy_Engineering["Degree"] = "Bachelor of Technology"
Energy_Engineering["Branch"] =  "Energy Engineering"
Energy_Engineering = Energy_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Engineering and Computational Mechanics (4 Years, Bachelor of Technology) # 116
Engineering_and_Computational_Mechanics  = df[df["Program"] == "Engineering and Computational Mechanics (4 Years, Bachelor of Technology)"]
Engineering_and_Computational_Mechanics["Duration"] = "4 Years"
Engineering_and_Computational_Mechanics["Degree"] = "Bachelor of Technology"
Engineering_and_Computational_Mechanics["Branch"] =  "Engineering and Computational Mechanics"
Engineering_and_Computational_Mechanics = Engineering_and_Computational_Mechanics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Materials Engineering (4 Years, Bachelor of Technology) # 117
Materials_Engineering  = df[df["Program"] == "Materials Engineering (4 Years, Bachelor of Technology)"]
Materials_Engineering["Duration"] = "4 Years"
Materials_Engineering["Degree"] = "Bachelor of Technology"
Materials_Engineering["Branch"] =  "Materials Engineering"
Materials_Engineering = Materials_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Mineral and Metallurgical Engineering (4 Years, Bachelor of Technology) # 118
Mineral_and_Metallurgical_Engineering  = df[df["Program"] == "Mineral and Metallurgical Engineering (4 Years, Bachelor of Technology)"]
Mineral_and_Metallurgical_Engineering["Duration"] = "4 Years"
Mineral_and_Metallurgical_Engineering["Degree"] = "Bachelor of Technology"
Mineral_and_Metallurgical_Engineering["Branch"] =  "Mineral and Metallurgical Engineering"
Mineral_and_Metallurgical_Engineering = Mineral_and_Metallurgical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Biosciences and Bioengineering (4 Years, Bachelor of Technology) # 119
Biosciences_and_Bioengineering  = df[df["Program"] == "Biosciences and Bioengineering (4 Years, Bachelor of Technology)"]
Biosciences_and_Bioengineering["Duration"] = "4 Years"
Biosciences_and_Bioengineering["Degree"] = "Bachelor of Technology"
Biosciences_and_Bioengineering["Branch"] =  "Biosciences and Bioengineering"
Biosciences_and_Bioengineering = Biosciences_and_Bioengineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Biomedical Engineering (4 Years, Bachelor of Technology) # 120
Biomedical_Engineering  = df[df["Program"] == "Biomedical Engineering (4 Years, Bachelor of Technology)"]
Biomedical_Engineering["Duration"] = "4 Years"
Biomedical_Engineering["Degree"] = "Bachelor of Technology"
Biomedical_Engineering["Branch"] =  "Biomedical Engineering"
Biomedical_Engineering = Biomedical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Biotechnology and Bioinformatics (4 Years, Bachelor of Technology) # 121
Biotechnology_and_Bioinformatics  = df[df["Program"] == "Biotechnology and Bioinformatics (4 Years, Bachelor of Technology)"]
Biotechnology_and_Bioinformatics["Duration"] = "4 Years"
Biotechnology_and_Bioinformatics["Degree"] = "Bachelor of Technology"
Biotechnology_and_Bioinformatics["Branch"] =  "Biotechnology and Bioinformatics"
Biotechnology_and_Bioinformatics = Biotechnology_and_Bioinformatics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Computational Engineering (4 Years, Bachelor of Technology) # 122
Biotechnology_and_Bioinformatics  = df[df["Program"] == "Computational Engineering (4 Years, Bachelor of Technology)"]
Biotechnology_and_Bioinformatics["Duration"] = "4 Years"
Biotechnology_and_Bioinformatics["Degree"] = "Bachelor of Technology"
Biotechnology_and_Bioinformatics["Branch"] =  "Computer Science and Engineering"
Biotechnology_and_Bioinformatics = Biotechnology_and_Bioinformatics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Industrial Chemistry (4 Years, Bachelor of Technology) # 123
Industrial_Chemistry  = df[df["Program"] == "Industrial Chemistry (4 Years, Bachelor of Technology)"]
Industrial_Chemistry["Duration"] = "4 Years"
Industrial_Chemistry["Degree"] = "Bachelor of Technology"
Industrial_Chemistry["Branch"] =  "Industrial Chemistry"
Industrial_Chemistry = Industrial_Chemistry.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Artificial Intelligence and Data Science (4 Years, Bachelor of Technology) # 124
Artificial_Intelligence_and_Data_Science  = df[df["Program"] == "Artificial Intelligence and Data Science (4 Years, Bachelor of Technology)"]
Artificial_Intelligence_and_Data_Science["Duration"] = "4 Years"
Artificial_Intelligence_and_Data_Science["Degree"] = "Bachelor of Technology"
Artificial_Intelligence_and_Data_Science["Branch"] =  "Artificial Intelligence and Data Science"
Artificial_Intelligence_and_Data_Science = Artificial_Intelligence_and_Data_Science.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Civil and Infrastructure Engineering (4 Years, Bachelor of Technology)  # 125
Civil_and_Infrastructure_Engineering  = df[df["Program"] == "Civil and Infrastructure Engineering (4 Years, Bachelor of Technology)"]
Civil_and_Infrastructure_Engineering["Duration"] = "4 Years"
Civil_and_Infrastructure_Engineering["Degree"] = "Bachelor of Technology"
Civil_and_Infrastructure_Engineering["Branch"] =  "Civil and Infrastructure Engineering"
Civil_and_Infrastructure_Engineering = Civil_and_Infrastructure_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Statistics and Data Science (4 Years, Bachelor of Science)  # 126
Statistics_and_Data_Science  = df[df["Program"] == "Statistics and Data Science (4 Years, Bachelor of Science)"]
Statistics_and_Data_Science["Duration"] = "4 Years"
Statistics_and_Data_Science["Degree"] = "Bachelor of Science"
Statistics_and_Data_Science["Branch"] =  "Statistics and Data Science"
Statistics_and_Data_Science = Statistics_and_Data_Science.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Applied Geology (4 Years, Bachelor of Science)  # 127
Applied_Geology  = df[df["Program"] == "Applied Geology (4 Years, Bachelor of Science)"]
Applied_Geology["Duration"] = "4 Years"
Applied_Geology["Degree"] = "Bachelor of Science"
Applied_Geology["Branch"] =  "Applied Geology"
Applied_Geology = Applied_Geology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Exploration Geophysics (4 Years, Bachelor of Science)  # 128
Exploration_Geophysics  = df[df["Program"] == "Exploration Geophysics (4 Years, Bachelor of Science)"]
Exploration_Geophysics["Duration"] = "4 Years"
Exploration_Geophysics["Degree"] = "Bachelor of Science"
Exploration_Geophysics["Branch"] =  "Exploration Geophysics"
Exploration_Geophysics = Exploration_Geophysics.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Mathematics and Computing (4 Years, Bachelor of Science)  # 129
Mathematics_and_Computing_  = df[df["Program"] == "Mathematics and Computing (4 Years, Bachelor of Science)"]
Mathematics_and_Computing_["Duration"] = "4 Years"
Mathematics_and_Computing_["Degree"] = "Bachelor of Science"
Mathematics_and_Computing_["Branch"] =  "Mathematics and Computing"
Mathematics_and_Computing_ = Mathematics_and_Computing_.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Chemical Sciences (5 Years, Bachelor of Science and Master of Science (Dual Degree))  # 130
Chemical_Sciences_Dual  = df[df["Program"] == "Chemical Sciences (5 Years, Bachelor of Science and Master of Science (Dual Degree))"]
Chemical_Sciences_Dual["Duration"] = "4 Years"
Chemical_Sciences_Dual["Degree"] = "Bachelor and Master of Science"
Chemical_Sciences_Dual["Branch"] =  "Chemical Sciences"
Chemical_Sciences_Dual = Chemical_Sciences_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Economics (5 Years, Bachelor of Science and Master of Science (Dual Degree))  # 131
Economics_Dual  = df[df["Program"] == "Economics (5 Years, Bachelor of Science and Master of Science (Dual Degree))"]
Economics_Dual["Duration"] = "4 Years"
Economics_Dual["Degree"] = "Bachelor and Master of Science"
Economics_Dual["Branch"] =  "Economics"
Economics_Dual = Economics_Dual.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Mathematics & Computing (5 Years, Bachelor of Science and Master of Science (Dual Degree))  # 132
Mathematics_and_Computing_Dual_  = df[df["Program"] == "Mathematics & Computing (5 Years, Bachelor of Science and Master of Science (Dual Degree))"]
Mathematics_and_Computing_Dual_["Duration"] = "4 Years"
Mathematics_and_Computing_Dual_["Degree"] = "Bachelor and Master of Science"
Mathematics_and_Computing_Dual_["Branch"] =  "Mathematics and Computing Dual Degree"
Mathematics_and_Computing_Dual_ = Mathematics_and_Computing_Dual_.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 

# Mechatronics Engineering (4 Years, Bachelor of Technology)  # 133
Mechatronics_Engineering  = df[df["Program"] == "Mechatronics Engineering (4 Years, Bachelor of Technology)"]
Mechatronics_Engineering["Duration"] = "4 Years"
Mechatronics_Engineering["Degree"] = "Bachelor of Technology"
Mechatronics_Engineering["Branch"] =  "Mechatronics_Engineering"
Mechatronics_Engineering = Mechatronics_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Chemical and Biochemical Engineering (4 Years, Bachelor of Technology)  # 134
Chemical_and_Biochemical_Engineering  = df[df["Program"] == "Chemical and Biochemical Engineering (4 Years, Bachelor of Technology)"]
Chemical_and_Biochemical_Engineering["Duration"] = "4 Years"
Chemical_and_Biochemical_Engineering["Degree"] = "Bachelor of Technology"
Chemical_and_Biochemical_Engineering["Branch"] =  "Chemical and Biochemical Engineering"
Chemical_and_Biochemical_Engineering = Chemical_and_Biochemical_Engineering.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Interdisciplinary Sciences (5 Years, Bachelor of Science and Master of Science (Dual Degree))  # 135
Interdisciplinary_Sciences  = df[df["Program"] == "Interdisciplinary Sciences (5 Years, Bachelor of Science and Master of Science (Dual Degree))"]
Interdisciplinary_Sciences["Duration"] = "4 Years"
Interdisciplinary_Sciences["Degree"] = "Bachelor and Master of Science"
Interdisciplinary_Sciences["Branch"] =  "Interdisciplinary Sciences"
Interdisciplinary_Sciences = Interdisciplinary_Sciences.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Electrical Engineering (IC Design and Technology) (4 Years, Bachelor of Technology)   # 136
Electrical_Engineering_IC_Design_and_Technology  = df[df["Program"] == "Electrical Engineering (IC Design and Technology) (4 Years, Bachelor of Technology)"]
Electrical_Engineering_IC_Design_and_Technology["Duration"] = "4 Years"
Electrical_Engineering_IC_Design_and_Technology["Degree"] = "Bachelor of Science"
Electrical_Engineering_IC_Design_and_Technology["Branch"] =  "Electrical Engineering IC Design and Technology"
Electrical_Engineering_IC_Design_and_Technology = Electrical_Engineering_IC_Design_and_Technology.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 
 
# Chemistry with Specialization (4 Years, Bachelor of Science)    # 137
Chemistry_with_Specialization  = df[df["Program"] == "Chemistry with Specialization (4 Years, Bachelor of Science)"]
Chemistry_with_Specialization["Duration"] = "4 Years"
Chemistry_with_Specialization["Degree"] = "Bachelor of Science"
Chemistry_with_Specialization["Branch"] =  "Chemistry with Specialization"
Chemistry_with_Specialization = Chemistry_with_Specialization.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"]) 

# Physics with Specialization (4 Years, Bachelor of Science)    # 137
Physics_with_Specialization  = df[df["Program"] == "Physics with Specialization (4 Years, Bachelor of Science)"]
Physics_with_Specialization["Duration"] = "4 Years"
Physics_with_Specialization["Degree"] = "Bachelor of Science"
Physics_with_Specialization["Branch"] =  "Physics with Specialization"
Physics_with_Specialization = Physics_with_Specialization.drop(columns=["Program","Unnamed: 0.1","Unnamed: 0"])
# Out:
# C:\Users\riya\AppData\Local\Temp\ipykernel_9416\3707135884.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Computer_Science_and_Engineering["Duration"] = "4 Years"
# C:\Users\riya\AppData\Local\Temp\ipykernel_9416\3707135884.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Computer_Science_and_Engineering["Degree"] = "Bachelor of Technology"
# C:\Users\riya\AppData\Local\Temp\ipykernel_9416\3707135884.py:5: SettingWithCopyWarning:
# ...

# %%
data_list = [ 
            
            Aerospace_Engineering,
            Aerospace_Engineering_Dual,
            Agricultural_and_Food_Engineering,
            Agricultural_and_Food_Engineering_Dual_Any_Specialization,
            Applied_Geology,
            Applied_Geophysics,
            Applied_Mathematics,
            Architecture,
            Artificial_Intelligence,
            Artificial_Intelligence_and_Data_Science,
            Bio_Engineering,
            Bio_Engineering_Dual,
            Bio_Technology,
            Biochemical_Engineering_and_Biotechnology,
            Biochemical_Engineering_Dual_Biochemical_Engineering_and_Biotechnology,
            Bioengineering_Dual_Biomedical_Technology,
            Biological_Engineering_Dual,
            Biological_Sciences_and_Bioengineering,
            Biological_Sciences_Dual,
            Biomedical_Engineering,
            Biosciences_and_Bioengineering,
            Biotechnology_and_Biochemical_Engineering,
            Biotechnology_and_Biochemical_Engineering_Dual,
            Biotechnology_and_Bioinformatics,
            BS_in_Mathematics,
            Ceramic_Engineering,
            Ceramic_Engineering_Dual,
            Chemical_and_Biochemical_Engineering,
            Chemical_Engineering,
            Chemical_Science_and_Technology,
            Chemical_Sciences_Dual,
            Chemistry,
            Chemistry_Integrated,
            Chemistry_with_Specialization,
            Civil_and_Infrastructure_Engineering,
            Civil_Engineering,
            Civil_Engineering_Dual,
            Civil_Engineering_Dual_Any_Specialization,
            Civil_Engineering_Dual_Environmental_Engineering,
            Civil_Engineering_Dual_Structural_Engineering,
            Civil_Engineering_Dual_Transportation_Engineering,
            Computer_Science_and_Engineering,
            Computer_Science_and_Engineering_Dual,
            Data_Science_and_Artificial_Intelligence,
            Data_Science_and_Engineering,
            Earth_Engineering,
            Economics,
            Economics_Dual,
            Economics_Integrated,
            Electrical_Engineering,
            Electrical_Engineering_Dual,
            Electrical_Engineering_Dual_Any_Specialization,
            Electrical_Engineering_Dual_Communications_and_Signal_Processing,
            Electrical_Engineering_Dual_Microelectronics,
            Electrical_Engineering_Dual_Power_Electronics,
            Electrical_Engineering_Dual_Power_Electronics_and_Drives,
            Electrical_Engineering_IC_Design_and_Technology,
            Electrical_Engineering_Powar_and_Automation,
            Electronics_and_Communication_Engineering,
            Electronics_and_Electrical_Communication_Engineering,
            Electronics_and_Electrical_Communication_Engineering_Dual_Any_Specialization,
            Electronics_and_Electrical_Engineering,
            Electronics_and_Instrumentation_Engineering,
            Electronics_Engineering,
            Energy_Engineering,
            Energy_Engineering_Dual_Energy_Systems,
            Engineering_and_Computational_Mechanics,
            Engineering_Design_Dual,
            Engineering_Physics,
            Engineering_Physics_Dual,
            Engineering_Science,
            Environmental_Engineering,
            Environmental_Science_and_Engineering_Dual,
            Exploration_Geophysics,
            Geological_Technology_Integrated,
            Geophysical_Technology_Integrated,
            Industrial_and_Systems_Engineering,
            Industrial_and_Systems_Engineering_dual_Industrial_and_Systems_Engineering_and_Management,
            Industrial_Chemistry,
            Industrial_Chemistry_Dual,
            Instrumentation_Engineering,
            Interdisciplinary_Sciences,
            Manufacturing_Science_and_Engineering,
            Manufacturing_Science_and_Engineering_Dual_Industrial_and_Systems_Engineering_and_Management,
            Materials_Engineering,
            Materials_Science_and_Metallurgical_Engineering,
            Materials_Science_and_Technology_Dual,
            Materials_Science_Engineering,
            Mathematics_and_Computing,
            Mathematics_and_Computing_,
            Mathematics_and_Computing_Dual,
            Mathematics_and_Computing_Dual_,
            Mathematics_and_Computing_Integrated,
            Mathematics_and_Scientific_Computing,Mineral_and_Metallurgical_Engineering,
            Mechanical_Engineering,
            Mechanical_Engineering_Dual,
            Mechanical_Engineering_Dual_Any_Specialization,
            Mechanical_Engineering_Dual_Computer_Integrated_Manufacturing,
            Mechanical_Engineering_Dual_Manufacturing_Engineering,
            Mechanical_Engineering_Dual_System_Design,
            Mechanical_Engineering_Dual_Thermal_Science,
            Mechatronics_Engineering,
            Metallurgical_and_Materials_Engineering_Dual,
            Metallurgical_and_Materials_Engineering_Dual_Materials_Science_and_Engineering,
            Metallurgical_Engineering,
            Metallurgical_Engineering_and_Materials_Science,
            Metallurgical_Engineering_and_Materials_Science_Dual,
            Metallurgical_Engineering_and_Materials_Science_Dual_Ceramics_and_Composites,
            Metallurgical_Engineering_and_Materials_Science_dual_Metallurgical_Process_Engineering,
            Metallurgical_Engineering_Dual,
            Mining_Machinery_Engineering,Mineral_Engineering,Mining_Engineering,
            Mining_Engineering_Dual,
            Mining_Machinery_Engineering,
            Mining_Safety_Engineering_Dual,
            Naval_Architecture_and_Ocean_Engineering,
            Naval_Architecture_and_Ocean_Engineering_Dual,
            Ocean_Engineering_and_Naval_Architecture,
            Ocean_Engineering_and_Naval_Architecture_Dual,
            Petroleum_Engineering,
            Pharmaceutical_Engineering_and_Technology,
            Pharmaceutical_Engineering_and_Technology_Dual,
            Physics,
            Physics_Dual,
            Physics_Integrated,
            Physics_with_Specialization,
            Polymer_Science_and_Engineering,
            Production_and_Industrial_Engineering,
            Quality_Engineering_Design_and_Manufacturing_Dual,
            Statistics_and_Data_Science,
            Textile_Technology
            
            
            ]

# %%
IIT = pd.concat(data_list , axis=0 , ignore_index=True)

# %%
def convert(value):
    if type(value) == str:
        value = value.strip('P')
        value= float(value)
    return float(value)

# %%
df.dtypes
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# Institute        object
# Program          object
# Quota            object
# Seat Type        object
# Gender           object
# Opening          object
# Closing          object
# Round           float64
# Year              int64
# dtype: object

# %%
for i in range(0,len(df["Opening"])):
    
    df["Opening"][i] = convert(df["Opening"][i])
# Out:
# C:\Users\riya\AppData\Local\Temp\ipykernel_9416\2467104416.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Opening"][i] = convert(df["Opening"][i])

# %%
for i in range(0,len(df["Closing"])):
    
    df["Closing"][i] = convert(df["Closing"][i])
# Out:
# C:\Users\riya\AppData\Local\Temp\ipykernel_9416\3236346521.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Closing"][i] = convert(df["Closing"][i])

# %%
df["Closing"] = df["Closing"].astype(int)

# %%
df["Opening"] = df["Opening"].astype(int)

# %%
df.dtypes
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# Institute        object
# Program          object
# Quota            object
# Seat Type        object
# Gender           object
# Opening           int32
# Closing           int32
# Round           float64
# Year              int64
# dtype: object

# %%
def fun(data):
    result =  df["Opening"]+df["Closing"]
    return result/2

# %%
IIT["Avg_ranking"] = fun(IIT)

# %%
IIT.shape
# Out:
# (71550, 12)

# %%
IIT.dtypes
# Out:
# Institute       object
# Quota           object
# Seat Type       object
# Gender          object
# Opening         object
# Closing         object
# Round          float64
# Year             int64
# Duration        object
# Degree          object
# Branch          object
# Avg_ranking    float64
# dtype: object

# %%
IIT.to_csv("IIT_Training_Data")

# %%
IIT.head(5)
# Out:
#                                Institute Quota   Seat Type  \
# 0  Indian Institute of Technology Bombay    AI        OPEN
# 1  Indian Institute of Technology Bombay    AI        OPEN
# 2  Indian Institute of Technology Bombay    AI  OPEN (PwD)
# 3  Indian Institute of Technology Bombay    AI     OBC-NCL
# 4  Indian Institute of Technology Bombay    AI     OBC-NCL
#
#                                   Gender Opening Closing  Round  Year  \
# 0                         Gender-Neutral    1040    1974    1.0  2018
# 1  Female-only (including Supernumerary)    1425    3605    1.0  2018
# 2                         Gender-Neutral      20      20    1.0  2018
# 3                         Gender-Neutral     703    1037    1.0  2018
# 4  Female-only (including Supernumerary)    1161    1185    1.0  2018
#
#   Duration                  Degree                 Branch  Avg_ranking
# 0  4 Years  Bachelor of Technology  Aerospace Engineering       4227.0
# ...
